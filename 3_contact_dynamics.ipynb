# %% [markdown]
# # Constrained dynamics
# This tutorial is a follow-up of the notebook 2. We now write a complete optimal control problem, where both the states and the controls are decided. In a first time, we work with a simple manipulator robot in free space. The dynamics can then be evaluated directly with the ABA algorithm. Then, we move to a humanoid robot with floating actuation and constrained dynamics, and use the corresponding algorithm of Pinocchio for that.

# %%
import magic_donotload
# Out:
# NB: as for all the tutorials, a magic command %do_not_load is introduced to hide the solutions to some questions. Change it for %load if you want to see (and execute) the solution.

# %% [markdown]
# ## Set up
# We will use the following tools:
# - the ur10 model (loaded by example-robot-data)
# - pinocchio.casadi for writing the problem and computing its derivatives
# - the IpOpt solver wrapped in casadi
# - the meshcat viewer
# - the pinocchio dynamics algorithms, namely ABA and constraintDynamics

# %%
# %load tp3/generated/free_import
import time
import unittest

import casadi
import example_robot_data as robex
import numpy as np
import pinocchio as pin
from pinocchio import casadi as cpin

from utils.meshcat_viewer_wrapper import MeshcatVisualizer

# %% [markdown]
# The notebook follows the same structure as notebook 2. Let's start with the manipulator robot.

# %% [markdown]
# ## Free dynamics
# We first write a manipulation problem, without contact. We search for the robot state trajectories $X=[x_0 ... x_T]$, with $x=(q,v)$ and control trajectories $U = [u_0 ... u_{T-1} ]$.
# We consider yet the robot to be fully actuatated, i.e. $u=\tau$ are the joint torques.
#
# The state evolution must be decided from the acceleration resulting from the actuation. This can be evaluated by the ABA algorithm.
# $$ \forall t=0..T-1, a_t = ABA(q_t,v_t,\tau_t) $$
# which is most commonly encountered under the matrix form $a_t = M(q_t)^{-1} ( \tau_t - b(q_t,v_t) )$, with $M$ the generalized mass matrix and $b$ the sum of nonlinear effects (coriolis, centrifugal, gravity).
#
# To simplify the writing, we will consider $A = [a_0 ... a_{T-1} ]$ to be part of the decision variables. Strictly speaking, we call this kind of variables a **slack**, as it is introduced for convenience (often for the convenience of the solver, here for the convenience of the syntax). The optimal control problem then writes:
#
# Decide:
# - $X = [ x_0 ... x_T ]$ the state trajectory (with $x = (robot.q0 + dq, v)$)
# - $A = [a_0 ... a_{T-1} ]$ the accelerations
# - $U = [u_0 ... u_{T-1} ]$ the controls (joint torques)
#
# Minimizing: $\sum_{t=0}^{T-1} v_t^2  + a_t^2 + e(q_T)^2$
#
# Subject to:
# - $x_0 = (robot.q0, 0)$
# - $\forall t=0..T-1$
# $$ a_t = ABA(q_t,v_t,\tau_t) $$
# $$ v_{t+1} = v_t + a_t \Delta t$$
# $$ q_{t+1} = q_t \oplus v_{t+1} \Delta t$$

# %% [markdown]
# ### Set up the model
# We simply copy the code of the previous notebook to load and display the robot.
# The robot is loaded with example-robot-data, but feel free to load your own.

# %%
# %load tp3/generated/free_ur10
robot = robex.load("ur10")
# Open the viewer
viz = MeshcatVisualizer(robot)
viz.display(robot.q0)

# The pinocchio model is what we are really interested by.
model = robot.model
data = model.createData()
# Out:
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7000/static/

# %% [markdown]
# The important frames are the effector and the target.

# %%
# %load tp3/generated/free_frames
Mtarget = pin.SE3(pin.utils.rotate("y", 3),
                  np.array([-0.5, 0.1, 0.2]))  # x,y,z
endEffectorFrameName = "tool0"
q0 = np.array([0, -3.14 / 2, 0, 0, 0, 0])

# %%
# %load tp3/generated/free_framesId
endEffector_ID = model.getFrameId(endEffectorFrameName)

# %% [markdown]
# The hyperparameters are defined as follow:

# %%
# %load tp3/generated/free_hyper
T = 50
DT = 0.002
w_vel = 0.1
w_conf = 5

# %% [markdown]
# Activate the visualization.

# %%
# %load tp3/generated/free_viz
# --- Add box to represent target
# Add a vizualization for the target
boxID = "world/box"
viz.addBox(boxID, [0.05, 0.1, 0.2], [1.0, 0.2, 0.2, 0.5])
# Add a vizualisation for the tip of the arm.
tipID = "world/blue"
viz.addBox(tipID, [0.08] * 3, [0.2, 0.2, 1.0, 0.5])


def displayScene(q, dt=1e-1):
    """
    Given the robot configuration, display:
    - the robot
    - a box representing endEffector_ID
    - a box representing Mtarget
    """
    pin.framesForwardKinematics(model, data, q)
    M = data.oMf[endEffector_ID]
    viz.applyConfiguration(boxID, Mtarget)
    viz.applyConfiguration(tipID, M)
    viz.display(q)
    time.sleep(dt)


def displayTraj(qs, dt=1e-2):
    for q in qs[1:]:
        displayScene(q, dt=dt)


displayScene(robot.q0)

# %%
viz.viewer.jupyter_cell()
# Out:
#             <div style="height: 400px; width: 100%; overflow-x: auto; overflow-y: hidden; resize: both">
#             <iframe src="http://127.0.0.1:7000/static/" style="width: 100%; height: 100%; border: none"></iframe>
#             </div>

# %% [markdown]
# Build Pinocchio Casadi model and data. This time, we need to compute the graph for the ABA algorithm. ABA takes the robot joint positions, velocities and torques, and returns the robot joint accelerations. An extended version also takes disturbance forces (expressed at every joint), but we will not use it here.

# %%
# %load tp3/generated/free_helpers
# --- Casadi helpers
cmodel = cpin.Model(model)
cdata = cmodel.createData()

nq = model.nq
nv = model.nv
nx = nq + nv
ndx = 2 * nv
cx = casadi.SX.sym("x", nx, 1)
cdx = casadi.SX.sym("dx", nv * 2, 1)
cq = cx[:nq]
cv = cx[nq:]
caq = casadi.SX.sym("a", nv, 1)
ctauq = casadi.SX.sym("tau", nv, 1)

# Compute kinematics casadi graphs
cpin.aba(cmodel, cdata, cq, cv, ctauq)
cpin.forwardKinematics(cmodel, cdata, cq, cv, caq)
cpin.updateFramePlacements(cmodel, cdata)

# %% [markdown]
# We cast ABA in a function to skip the SX/MX casadi syntax.

# %%
# %load tp3/generated/free_aba
# Sym graph for the aba operation
caba = casadi.Function("aba", [cx, ctauq], [cdata.ddq])

# %% [markdown]
# Similarly, we introduce a helper for the integration of the acceleration, as in the previous notebook.

# %%
# %load tp3/generated/free_cnext
# Sym graph for the integration operation x' = [ q+vDT+aDT**2, v+aDT ]
cnext = casadi.Function(
    "next",
    [cx, caq],
    [
        casadi.vertcat(
            cpin.integrate(cmodel, cx[:nq], cx[nq:] * DT + caq * DT**2),
            cx[nq:] + caq * DT,
        )
    ],
)

# %% [markdown]
# Finally, we need a helper for the operational target, as before.

# %%
# %load tp3/generated/free_error
# Sym graph for the operational error
error_tool = casadi.Function(
    "etool3", [cx], [
        cdata.oMf[endEffector_ID].translation - Mtarget.translation]
)

# %% [markdown]
# ### Write and solve
# We are now ready to formulate the problem. Follow the step for that.
#
# 1. Define the variables $X,A,U$.

# %%
# %load tp3/generated/free_ocp1
opti = casadi.Opti()
var_xs = [opti.variable(nx) for t in range(T + 1)]
var_as = [opti.variable(nv) for t in range(T)]
var_us = [opti.variable(nv) for t in range(T)]

# %% [markdown]
# 2. Compute the cost

# %%
# %load tp3/generated/free_ocp2
totalcost = 0
# Define the running cost
for t in range(T):
    totalcost += 1e-3 * DT * casadi.sumsqr(var_xs[t][nq:])
    totalcost += 1e-4 * DT * casadi.sumsqr(var_as[t])
totalcost += 1e4 * casadi.sumsqr(error_tool(var_xs[T]))

# %% [markdown]
# 3. Enforce the initial constraint. You can also add a terminal velocity constraint if you like.

# %%
# %load tp3/generated/free_ocp3
opti.subject_to(var_xs[0][:nq] == robot.q0)
opti.subject_to(var_xs[0][nq:] == 0)  # zero initial velocity
opti.subject_to(var_xs[T][nq:] == 0)  # zero terminal velocity

# %% [markdown]
# 4. Define the dynamics, by both enforcing that acceleration matches ABA (var_a = ABA(q,v,tau)), and that the next state results from the integration of the acceleration.

# %%
# %load tp3/generated/free_integration
for t in range(T):
    opti.subject_to(caba(var_xs[t], var_us[t]) == var_as[t])
    opti.subject_to(cnext(var_xs[t], var_as[t]) == var_xs[t + 1])

# %% [markdown]
# 5. Solve

# %%
# %load tp3/generated/free_ocp5
# SOLVE
opti.minimize(totalcost)
opti.solver("ipopt")  # set numerical backend
opti.callback(lambda i: displayScene(opti.debug.value(var_xs[-1][:nq])))

# Caution: in case the solver does not converge, we are picking the candidate values
# at the last iteration in opti.debug, and they are NO guarantee of what they mean.
try:
    sol = opti.solve_limited()
    sol_xs = [opti.value(var_x) for var_x in var_xs]
    sol_as = [opti.value(var_a) for var_a in var_as]
    sol_us = [opti.value(var_u) for var_u in var_us]
except:
    print("ERROR in convergence, plotting debug info.")
    sol_xs = [opti.debug.value(var_x) for var_x in var_xs]
    sol_as = [opti.debug.value(var_a) for var_a in var_as]
    sol_us = [opti.debug.value(var_u) for var_u in var_us]
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:     7818
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     6015
#
# Total number of variables............................:     1212
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      918
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.8967411e+04 2.93e+01 7.73e-03  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.7951552e+04 4.12e+00 2.36e+00  -1.0 1.25e+02  -4.0 1.00e+00 1.00e+00h  1
#    2  2.1173215e+04 2.88e+02 5.13e+01  -1.0 5.17e+02  -4.5 1.00e+00 1.00e+00f  1
#    3  1.2885856e+04 2.57e+04 1.59e+03  -1.0 8.52e+03  -5.0 1.00e+00 1.00e+00f  1
#    4  9.6454133e+03 3.80e+03 3.47e+03  -1.0 1.05e+04  -4.5 1.00e+00 1.00e+00h  1
#    5  9.1634600e+03 6.41e+02 1.23e+03  -1.0 1.98e+03  -4.1 1.00e+00 1.00e+00h  1
#    6  7.7654003e+03 2.41e+03 5.46e+01  -1.0 4.45e+02  -4.6 1.00e+00 1.00e+00h  1
#    7  5.9659444e+03 2.15e+03 1.15e+01  -1.0 4.50e+02  -5.1 1.00e+00 1.00e+00h  1
#    8  4.3261379e+03 2.13e+03 1.25e+01  -1.0 4.76e+02  -5.5 1.00e+00 1.00e+00h  1
#    9  2.6342924e+03 4.33e+02 3.25e+00  -1.0 1.23e+03  -6.0 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.0420948e+03 9.97e+02 5.67e+00  -1.0 1.92e+03  -6.5 1.00e+00 1.00e+00h  1
#   11  6.8607111e+02 1.81e+03 5.23e+00  -1.0 1.67e+03  -7.0 1.00e+00 1.00e+00h  1
#   12  5.9679445e+02 1.13e+02 4.54e-01  -1.0 1.61e+03  -7.4 1.00e+00 1.00e+00h  1
#   13  5.3133586e+02 6.95e+01 9.94e-02  -1.0 1.85e+03  -7.9 1.00e+00 1.00e+00h  1
#   14  4.4773769e+02 2.34e+02 1.40e-01  -1.0 4.28e+03  -8.4 1.00e+00 1.00e+00h  1
#   15  3.7312805e+02 6.05e+02 4.23e-01  -1.0 7.84e+03  -8.9 1.00e+00 1.00e+00h  1
#   16  3.2891464e+02 7.66e+02 1.33e+00  -1.0 9.48e+03  -9.4 1.00e+00 1.00e+00h  1
#   17  3.1252999e+02 3.64e+02 7.88e-01  -1.0 1.03e+04  -9.8 1.00e+00 1.00e+00h  1
#   18  3.0566680e+02 9.64e+02 1.11e+00  -1.0 2.55e+04    -  1.00e+00 1.00e+00h  1
#   19  3.0478487e+02 7.76e+01 1.45e-01  -1.0 2.15e+03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  3.0458292e+02 9.11e+01 2.47e-01  -1.0 1.16e+03    -  1.00e+00 1.00e+00h  1
#   21  3.0454110e+02 5.01e+00 1.49e-02  -1.0 3.95e+02    -  1.00e+00 1.00e+00h  1
#   22  3.0453945e+02 1.18e+00 3.44e-03  -1.0 1.51e+02    -  1.00e+00 1.00e+00h  1
#   23  3.0453944e+02 1.57e-03 4.66e-06  -1.0 6.24e+00    -  1.00e+00 1.00e+00h  1
#   24  3.0453944e+02 5.93e-08 1.72e-10  -3.8 3.42e-02    -  1.00e+00 1.00e+00h  1
#   25  3.0453944e+02 1.53e-09 1.73e-14  -8.6 3.75e-07    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 25
#
#                                    (scaled)                 (unscaled)
# Objective...............:   6.1772581224578884e+00    3.0453944316312607e+02
# Dual infeasibility......:   1.7319479184152442e-14    8.5385205572702598e-13
# Constraint violation....:   1.1308429748169146e-09    1.5304522094083950e-09
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   1.1308429748169146e-09    1.5304522094083950e-09
#
#
# Number of objective function evaluations             = 26
# Number of objective gradient evaluations             = 26
# Number of equality constraint evaluations            = 26
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 26
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 25
# Total seconds in IPOPT                               = 3.596
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
# callback_fun  |  56.91ms (  2.19ms)   2.68 s (103.06ms)        26
#        nlp_f  | 581.00us ( 22.35us) 580.86us ( 22.34us)        26
#        nlp_g  |  11.76ms (452.19us)  11.74ms (451.37us)        26
#   nlp_grad_f  | 978.00us ( 36.22us) 970.95us ( 35.96us)        27
#   nlp_hess_l  | 648.17ms ( 25.93ms) 648.22ms ( 25.93ms)        25
#    nlp_jac_g  | 149.54ms (  5.54ms) 149.44ms (  5.53ms)        27
#        total  | 974.89ms (974.89ms)   3.60 s (  3.60 s)         1

# %% [markdown]
# And finally, display the result.

# %%
# %load tp3/generated/free_ocp6
print("***** Display the resulting trajectory ...")
displayScene(robot.q0, 1)
displayTraj([x[:nq] for x in sol_xs], DT)
# Out:
# ***** Display the resulting trajectory ...

# %% [markdown]
# ## Contact dynamics
# Next, we now consider a humanoid robot in contact with the ground. We will only enforce here a bilateral contact, i.e. the solver will never "discover" that the robot can relax the contact and start walking.

# %%
# %load tp3/generated/contact_talos
robot = robex.load("talos_legs")
# Open the viewer
viz = MeshcatVisualizer(robot)
viz.display(robot.q0)

# The pinocchio model is what we are really interested by.
model = robot.model
data = model.createData()
# Out:
# /home/matheecs/Code/jnrh2023/myenv/lib/python3.10/site-packages/cmeel.prefix/lib/python3.10/site-packages/example_robot_data/robots_loader.py:319: UserWarning: Deprecated member. Use Frame.parentJoint instead.
#   if f.parent < legMaxId:
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7001/static/

# %%
from types import SimpleNamespace

# %%
# %load tp3/generated/contact_frames
Mtarget = pin.SE3(pin.utils.rotate("y", 3),
                  np.array([-0.1, 0.2, 0.45094]))  # x,y,z
contacts = [SimpleNamespace(name="left_sole_link",
                            type=pin.ContactType.CONTACT_6D)]
endEffectorFrameName = "right_sole_link"

# %% [markdown]
# ### Using the constraint dynamics solver
# Our model now is in contact with the ground. A first solution is to extend the previous notebook: consider an explicit motion constraint on the acceleration, and as above, introduce the joint torques as a decision variable. Then we also have to decide the contact forces. This works, yet it implies many more variables; it is not easy to generalize, as new contacts would imply to change the structure of the trajectory optimization problem; and the efficiency of the trajectory solver to handle the dynamics is not ideal.
#
# Instead, we will change the dynamics to directly account for the contact constraint at that level. Then, the contact forces and the contact motion constraint are implicit for the trajectory solver, and the forces become a function of the torque rather than an explicit variable.
#
# For that, we will use the pin.constraintDynamics function of Pinocchio. This method is described in details in the paper of [Justin Carpentier (2021)](https://inria.hal.science/hal-03271811/file/rss-proximal-and-sparse.pdf). From a syntax point of view, it works nearly as ABA: you just need to specify the contact models.
#
# Justin Carpentier et al (2021). Proximal and sparse resolution of constrained dynamic equations. In Robotics: Science and Systems.

# %%
# %load tp3/generated/contact_framesId
endEffector_ID = model.getFrameId(endEffectorFrameName)
for c in contacts:
    c.id = model.getFrameId(c.name)
    assert c.id < len(model.frames)
    c.jid = model.frames[c.id].parentJoint
    c.placement = model.frames[c.id].placement
    c.model = pin.RigidConstraintModel(c.type, model, c.jid, c.placement)
contact_models = [c.model for c in contacts]

# %% [markdown]
# Here, the pin.RigidConstraintModel is used to store the contact type (3D or 6D implemented for now), the joint ID, and the placement of the contact location on the joint. Additionally, you can specify the location of the contact in the world if you want to use a Baumgart position corrector (we will not).

# %%
# %load tp3/generated/contact_contact_solver
# Baumgart correction
Kv = np.array([20.] * 6)
Kp = np.array([0.] * 6)
# Tuning of the proximal solver (minimal version)
prox_settings = pin.ProximalSettings(0, 1e-6, 1)

# %%
# %load tp3/generated/contact_contact_setting
contact_datas = [c.createData() for c in contact_models]
for c in contact_models:
    c.corrector.Kd = Kv
    c.corrector.Kp = Kp

# %% [markdown]
# The constraint solver is a proximal solver (see the algorithm explained by Justin Carpentier 2021), which we will use minimally here as defined by the proximal settings (using a single iteration). You can call it like this:

# %%
pin.initConstraintDynamics(model, data, contact_models)
q = robot.q0.copy()
v = np.zeros(model.nv)
tau = np.zeros(model.nv)
pin.constraintDynamics(model, data, q, v, tau, contact_models, contact_datas)
# Out:
# array([ -1.09796479,  -1.37267382,  -7.88771551,   8.20606128,
#         -3.76565864,   1.37070481,  -1.37070481,  -9.49136458,
#        -19.27689169,  49.77986436, -26.73731403,   1.28530331,
#         -2.43383966,  -9.04718988,   5.05175259,  -3.13190861,
#          0.16928539,  -0.19395264])

# %% [markdown]
# ### Formulation of the problem
#
# The problem is then very similar to the previous one. We simply need to take care to the constraint dynamics with the appropriate algorithm. The contact forces are then a hiden quantity inside the dynamics. We also need to take care to the underactuation which states that their are no direct actuation of the basis. This can be enforced by setting the torques as:
# $$\tau = [0_6, u]$$
#
# The problem can then be written as follow.
#
# Decide:
# - $X = [ x_0 ... x_T ]$ the state trajectory (with $x = (robot.q0 + dq, v)$)
# - $A = [a_0 ... a_{T-1} ]$ the accelerations
# - $U = [u_0 ... u_{T-1} ]$ the controls (actuated joint torques)
#
# Minimizing: $\sum_{t=0}^{T-1} v_t^2  + a_t^2 + e(q_T)^2$
#
# Subject to:
# - $x_0 = (robot.q0, 0)$
# - $\forall t=0..T-1$
# $$ \tau = [0_6,u_t]$$
# $$ a_t = ABA(q_t,v_t,\tau_t) $$
# $$ v_{t+1} = v_t + a_t \Delta t$$
# $$ q_{t+1} = q_t \oplus v_{t+1} \Delta t$$
#
# As previously, we need to define some helpers to get around the SX/MX syntax.

# %%
# %load tp3/generated/contact_helpers
# --- Casadi helpers
cmodel = cpin.Model(model)
cdata = cmodel.createData()
ccontact_models = [cpin.RigidConstraintModel(c) for c in contact_models]
ccontact_datas = [c.createData() for c in ccontact_models]
cprox_settings = cpin.ProximalSettings(
    prox_settings.absolute_accuracy, prox_settings.mu, prox_settings.max_iter
)
cpin.initConstraintDynamics(cmodel, cdata, ccontact_models)

nq = model.nq
nv = model.nv
nx = nq + nv
ndx = 2 * nv
cx = casadi.SX.sym("x", nx, 1)
cdx = casadi.SX.sym("dx", nv * 2, 1)
cq = cx[:nq]
cv = cx[nq:]
caq = casadi.SX.sym("a", nv, 1)
ctauq = casadi.SX.sym("tau", nv, 1)

# Compute kinematics casadi graphs
cpin.constraintDynamics(cmodel, cdata, cq, cv, ctauq,
                        ccontact_models, ccontact_datas)
cpin.forwardKinematics(cmodel, cdata, cq, cv, caq)
cpin.updateFramePlacements(cmodel, cdata)

# %% [markdown]
# Here the dynamics is evaluated using the constraint algorithm.
# As the robot has a free floating basis, we will use the integration on the state space $\mathcal{X}$ to take care of the Lie group structure.

# %%
# %load tp3/generated/contact_integrate
# Sym graph for the integration operation x,dx -> x(+)dx = [model.integrate(q,dq),v+dv]
cintegrate = casadi.Function(
    "integrate",
    [cx, cdx],
    [casadi.vertcat(cpin.integrate(cmodel, cx[:nq],
                    cdx[:nv]), cx[nq:] + cdx[nv:])],
)

# %% [markdown]
# The Euler integration is defined as previously.

# %%
# %load tp3/generated/contact_cnext
# Sym graph for the integration operation x' = [ q+vDT+aDT**2, v+aDT ]
cnext = casadi.Function(
    "next",
    [cx, caq],
    [
        casadi.vertcat(
            cpin.integrate(cmodel, cx[:nq], cx[nq:] * DT + caq * DT**2),
            cx[nq:] + caq * DT,
        )
    ],
)

# %% [markdown]
# The acceleration resulting from the forward dynamics will be used to enforce the slack variable $A$.

# %%
# %load tp3/generated/contact_aba
# Sym graph for the aba operation
caba = casadi.Function("fdyn", [cx, ctauq], [cdata.ddq])

# %% [markdown]
# Finally, the operational target is defined by:

# %%
# %load tp3/generated/contact_error
# Sym graph for the operational error
error_tool = casadi.Function(
    "etool3", [cx], [
        cdata.oMf[endEffector_ID].translation - Mtarget.translation]
)

# %% [markdown]
# ### Implementation of the OCP
#
# You can now implement the problem. Follow the steps.
#
# 1. Define the decision variables $X,A,U$. Remember that the states $x$ are implemented as small steps $dx$ from a reference state $x_0 = [robot.q0,0_{nv} ]$.

# %%
# %load tp3/generated/contact_ocp1
opti = casadi.Opti()
var_dxs = [opti.variable(ndx) for t in range(T + 1)]
var_as = [opti.variable(nv) for t in range(T)]
var_us = [opti.variable(nv - 6) for t in range(T)]
var_xs = [
    cintegrate(np.concatenate([robot.q0, np.zeros(nv)]), var_dx) for var_dx in var_dxs
]

# %% [markdown]
# 2. Compute the cost.

# %%
# %load tp3/generated/contact_ocp2
totalcost = 0
# Define the running cost
for t in range(T):
    totalcost += 1e-3 * DT * casadi.sumsqr(var_xs[t][nq:])
    totalcost += 1e-4 * DT * casadi.sumsqr(var_as[t])
totalcost += 1e1 * casadi.sumsqr(error_tool(var_xs[T]))

# %% [markdown]
# 3. Enforce the boundary conditions (on $x_0$, and also on $v_T$ if you like).

# %%
# %load tp3/generated/contact_ocp3
opti.subject_to(var_xs[0][:nq] == robot.q0)
opti.subject_to(var_xs[0][nq:] == 0)  # zero initial velocity
opti.subject_to(var_xs[T][nq:] == 0)  # zero terminal velocity

# %% [markdown]
# 4. Enforce the integration, (i) by setting $\tau$, then (ii) computing the acceleration by inverse dynamics and finally (iii) enforcing Euler integration.

# %%
# %load tp3/generated/contact_integration
for t in range(T):
    tau = casadi.vertcat(np.zeros(6), var_us[t])
    opti.subject_to(caba(var_xs[t], tau) == var_as[t])
    opti.subject_to(cnext(var_xs[t], var_as[t]) == var_xs[t + 1])

# %% [markdown]
# 5. Solve the problem

# %%
# %load tp3/generated/contact_ocp5
# SOLVE
opti.minimize(totalcost)
opti.solver("ipopt")  # set numerical backend
opti.callback(lambda i: displayScene(opti.debug.value(var_xs[-1][:nq])))

# Caution: in case the solver does not converge, we are picking the candidate values
# at the last iteration in opti.debug, and they are NO guarantee of what they mean.
try:
    sol = opti.solve_limited()
    sol_xs = [opti.value(var_x) for var_x in var_xs]
    sol_as = [opti.value(var_a) for var_a in var_as]
    sol_us = [opti.value(var_u) for var_u in var_us]
except:
    print("ERROR in convergence, plotting debug info.")
    sol_xs = [opti.debug.value(var_x) for var_x in var_xs]
    sol_as = [opti.debug.value(var_a) for var_a in var_as]
    sol_us = [opti.debug.value(var_u) for var_u in var_us]
# Out:
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:    55278
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:    46128
#
# Total number of variables............................:     3336
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     2805
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  2.9298679e+00 4.98e+01 9.02e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.9216466e+00 8.65e-02 7.27e-01  -1.0 5.63e+01  -4.0 1.00e+00 1.00e+00h  1
#    2  2.9020664e+00 1.59e-02 1.51e+12  -1.7 2.80e+01  -4.5 1.00e+00 1.00e+00h  1
#    3  2.9020664e+00 1.59e-02 1.56e+12  -1.7 6.69e-06  17.4 1.00e+00 1.00e+00h  1
#    4  2.9020664e+00 1.59e-02 1.71e+12  -1.7 2.20e-05  16.9 1.00e+00 1.00e+00h  1
#    5  2.9020664e+00 1.59e-02 2.33e+12  -1.7 9.00e-05  16.4 1.00e+00 1.00e+00h  1
#    6  2.9020664e+00 1.59e-02 1.16e+13  -1.7 1.34e-03  15.9 1.00e+00 1.00e+00h  1
#    7  2.9020664e+00 1.59e-02 1.65e+13  -1.7 7.18e-04  16.4 1.00e+00 1.00e+00h  1
#    8r 2.9020664e+00 1.59e-02 9.99e+02  -1.7 0.00e+00  15.9 0.00e+00 4.77e-07R 22
#    9r 2.9020580e+00 4.10e-03 9.61e+02  -1.7 1.26e+01    -  4.25e-02 1.25e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.9020580e+00 4.08e-03 2.51e+08  -1.7 9.82e-08  15.4 1.00e+00 1.00e+00h  1
#   11  2.9020580e+00 3.98e-03 4.96e+08  -1.7 5.82e-07  14.9 1.00e+00 1.00e+00h  1
#   12  2.9020580e+00 3.94e-03 7.14e+08  -1.7 2.51e-06  14.5 1.00e+00 1.00e+00h  1
#   13  2.9020580e+00 3.81e-03 8.40e+08  -1.7 8.87e-06  14.0 1.00e+00 1.00e+00h  1
#   14  2.9020580e+00 3.41e-03 7.45e+08  -1.7 2.36e-05  13.5 1.00e+00 1.00e+00h  1
#   15  2.9020579e+00 3.34e-03 2.55e+08  -1.7 3.87e-05  13.0 1.00e+00 1.00e+00H  1
#   16  2.9020579e+00 2.83e-03 1.98e+08  -1.7 5.65e-05  12.5 1.00e+00 1.00e+00h  1
#   17  2.9020578e+00 7.52e-03 1.37e+08  -1.7 1.17e-04  12.1 1.00e+00 1.00e+00h  1
#   18  2.9020574e+00 1.19e-02 4.63e+07  -1.7 1.19e-04  11.6 1.00e+00 1.00e+00h  1
#   19  2.9020562e+00 6.41e-03 3.46e+07  -1.7 2.66e-04  11.1 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  2.9020553e+00 9.39e-03 2.12e+07  -1.7 4.90e-04  10.6 1.00e+00 1.00e+00h  1
#   21  2.9020627e+00 7.93e-03 6.19e+06  -1.7 4.29e-04  10.2 1.00e+00 1.00e+00h  1
#   22  2.9021155e+00 3.50e-03 4.39e+06  -1.7 9.11e-04   9.7 1.00e+00 1.00e+00h  1
#   23  2.9023220e+00 2.98e-03 3.36e+06  -1.7 2.24e-03   9.2 1.00e+00 1.00e+00H  1
#   24  2.9028752e+00 4.12e-03 2.44e+06  -1.7 4.57e-03   8.7 1.00e+00 1.00e+00h  1
#   25  2.9036993e+00 6.21e-03 9.05e+05  -1.7 5.08e-03   8.3 1.00e+00 1.00e+00h  1
#   26  2.9036739e+00 4.53e-03 2.83e+05  -1.7 4.77e-03   7.8 1.00e+00 1.00e+00h  1
#   27  2.9036700e+00 4.51e-03 1.85e+16  -1.7 2.53e+03   7.3 1.00e+00 1.95e-03h 10
# WARNING: Problem in step computation; switching to emergency mode.
#   28r 2.9036700e+00 4.51e-03 9.96e+02  -1.7 0.00e+00  19.1 0.00e+00 0.00e+00R  1
#   29r 2.9036929e+00 5.37e-04 9.80e+02  -1.7 1.18e+00    -  2.20e-02 7.13e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  2.0681688e+00 6.16e+02 1.22e+11  -1.7 4.64e+03    -  1.00e+00 1.00e+00f  1
#   31  2.6344872e+00 5.98e+02 1.14e+11  -1.7 1.19e+01   8.0 1.00e+00 6.25e-02h  5
#   32  2.8669638e+00 5.79e+02 1.07e+11  -1.7 2.38e+01   7.5 1.00e+00 6.25e-02h  5
#   33  2.5639285e+00 3.15e+02 3.56e+11  -1.7 1.42e+01   7.9 1.00e+00 5.00e-01h  2
#   34  2.6318911e+00 2.54e+02 2.35e+12  -1.7 3.16e+00   9.7 1.00e+00 1.00e+00h  1
#   35  2.6347717e+00 2.74e+02 7.09e+12  -1.7 1.07e+00  11.0 1.00e+00 1.00e+00h  1
#   36  2.8567816e+00 2.75e+02 2.54e+22  -1.7 2.00e+05  10.6 1.00e+00 9.77e-04h 11
# WARNING: Problem in step computation; switching to emergency mode.
#   37r 2.8567816e+00 2.75e+02 9.99e+02   2.4 0.00e+00  18.4 0.00e+00 0.00e+00R  1
#   38r 3.1013568e+00 6.52e+01 9.73e+02   2.4 2.47e+05    -  2.91e-02 1.10e-03f  1
#   39r 3.6795435e+00 2.03e+01 9.51e+02   1.0 1.08e+04    -  4.80e-01 2.69e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40r 6.8977453e+00 6.27e+02 7.92e+02   1.0 4.08e+04    -  1.00e+00 1.25e-01f  1
#   41r 7.2642255e+00 4.89e+02 5.64e+02   1.0 5.08e+02  -4.0 1.00e+00 2.21e-01f  1
#   42r 5.9362775e+00 2.74e+02 1.26e+02   1.0 5.01e+02  -4.5 1.00e+00 7.84e-01f  1
#   43r 5.3691565e+00 4.19e+02 3.36e+02   1.0 2.96e+03    -  1.00e+00 5.40e-01f  1
#   44r 2.1516716e+00 2.63e+02 2.03e+02   1.0 2.66e+03    -  1.00e+00 5.54e-01f  1
#   45r 2.2884604e+00 1.94e+02 5.51e+01   1.0 2.08e+03    -  1.00e+00 1.00e+00f  1
#   46  1.7623241e+00 3.99e+02 5.30e+01  -1.7 6.38e+03    -  1.00e+00 5.00e-01h  2
#   47r 1.7623241e+00 3.99e+02 9.99e+02   2.6 0.00e+00  19.9 0.00e+00 4.77e-07R 22
#   48r 1.8621343e+00 9.61e+01 9.72e+02   2.6 3.79e+05    -  6.07e-02 1.09e-03f  1
#   49  1.4136521e+00 1.42e+02 7.65e+00  -1.7 2.79e+03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  1.4308896e+00 1.25e+02 2.36e+08  -1.7 7.23e+03    -  1.00e+00 1.25e-01h  4
#   51  1.4308896e+00 1.25e+02 4.00e+13  -1.7 1.43e-06  19.4 1.00e+00 1.00e+00h  1
#   52  1.4308896e+00 1.25e+02 7.99e+13  -1.7 8.58e-06  19.0 1.00e+00 1.00e+00h  1
#   53  1.4308896e+00 1.25e+02 1.20e+14  -1.7 3.86e-05  18.5 1.00e+00 1.00e+00h  1
#   54  1.4308896e+00 1.25e+02 1.59e+14  -1.7 1.54e-04  18.0 1.00e+00 1.00e+00h  1
#   55  1.4308896e+00 1.24e+02 1.98e+14  -1.7 5.73e-04  17.5 1.00e+00 1.00e+00h  1
#   56  1.4308896e+00 1.22e+02 2.34e+14  -1.7 2.03e-03  17.1 1.00e+00 1.00e+00h  1
#   57  1.4308896e+00 1.14e+02 2.61e+14  -1.7 6.80e-03  16.6 1.00e+00 1.00e+00h  1
#   58  1.4308896e+00 8.88e+01 2.61e+14  -1.7 2.04e-02  16.1 1.00e+00 1.00e+00h  1
#   59  1.4308895e+00 4.70e+01 2.04e+14  -1.7 4.84e-02  15.6 1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  1.4308893e+00 9.02e+01 1.35e+14  -1.7 1.04e-01  15.2 1.00e+00 1.00e+00H  1
#   61  1.4308888e+00 7.77e+01 4.84e+13  -1.7 1.62e-01  14.7 1.00e+00 1.00e+00H  1
#   62  1.4308895e+00 7.39e+01 2.52e+13  -1.7 5.39e-01  14.2 1.00e+00 1.00e+00H  1
#   63  1.4308922e+00 2.91e+02 2.36e+13  -1.7 5.66e-01  13.7 1.00e+00 1.00e+00s 22
#   64  1.4308939e+00 1.60e+02 2.34e+13  -1.7 1.69e-01  14.1 1.00e+00 1.00e+00s 22
#   65r 1.4308939e+00 1.60e+02 9.99e+02   2.2 0.00e+00  14.1 0.00e+00 0.00e+00R  1
#   66r 1.4405103e+00 4.73e+01 9.76e+02   2.2 1.46e+05    -  2.75e-02 1.08e-03f  1
#   67r 1.3609783e+00 1.92e+01 9.31e+02   0.8 1.14e+04    -  7.89e-02 2.37e-02f  1
#   68  1.4112700e+00 4.72e+01 4.58e+00  -1.7 3.99e+03    -  1.00e+00 2.50e-01h  3
#   69  1.4455672e+00 5.25e+01 5.62e+00  -1.7 2.69e+03    -  1.00e+00 2.50e-01h  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  1.4455678e+00 2.00e+01 1.82e+12  -1.7 4.34e-02  13.6 1.00e+00 1.00e+00h  1
#   71  1.4455705e+00 1.81e+01 1.57e+12  -1.7 1.10e-01  13.1 1.00e+00 1.00e+00h  1
#   72  1.4455716e+00 1.78e+01 5.73e+11  -1.7 2.14e-01  12.7 1.00e+00 1.00e+00H  1
#   73  1.4455707e+00 1.30e+01 4.82e+11  -1.7 3.67e-02  13.1 1.00e+00 1.00e+00h  1
#   74  1.4455700e+00 1.23e+01 6.04e+11  -1.7 1.82e-02  13.5 1.00e+00 1.00e+00h  1
#   75  1.4455671e+00 1.22e+01 7.30e+11  -1.7 6.55e-02  13.0 1.00e+00 1.00e+00h  1
#   76  1.4455658e+00 1.25e+01 7.76e+11  -1.7 2.65e-02  13.5 1.00e+00 1.00e+00h  1
#   77  1.4455653e+00 1.26e+01 7.91e+11  -1.7 1.02e-02  13.9 1.00e+00 1.00e+00h  1
#   78  1.4556187e+00 1.26e+01 6.64e+21  -1.7 1.85e+04  13.4 1.00e+00 1.95e-03h 10
# WARNING: Problem in step computation; switching to emergency mode.
#   79r 1.4556187e+00 1.26e+01 9.99e+02   1.1 0.00e+00  19.3 0.00e+00 0.00e+00R  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80r 1.4570668e+00 3.20e+00 9.89e+02   1.1 1.25e+04    -  4.63e-02 1.00e-03f  1
#   81  1.4691161e+00 3.26e+00 4.28e+00  -1.7 4.29e+03    -  1.00e+00 1.56e-02h  7
#   82  1.4818504e+00 3.30e+00 4.21e+00  -1.7 4.15e+03    -  1.00e+00 1.56e-02h  7
#   83  1.4951716e+00 3.34e+00 4.14e+00  -1.7 4.01e+03    -  1.00e+00 1.56e-02h  7
#   84  1.5089886e+00 3.37e+00 4.08e+00  -1.7 3.87e+03    -  1.00e+00 1.56e-02h  7
#   85  1.5232168e+00 3.40e+00 4.01e+00  -1.7 3.74e+03    -  1.00e+00 1.56e-02h  7
#   86  1.5377780e+00 3.42e+00 3.95e+00  -1.7 3.61e+03    -  1.00e+00 1.56e-02h  7
#   87  1.5525997e+00 3.44e+00 3.89e+00  -1.7 3.48e+03    -  1.00e+00 1.56e-02h  7
#   88  1.5676147e+00 3.45e+00 4.23e+00  -1.7 3.36e+03    -  1.00e+00 1.56e-02h  7
#   89  1.5827608e+00 3.46e+00 4.59e+00  -1.7 3.24e+03    -  1.00e+00 1.56e-02h  7
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90  1.5979808e+00 3.47e+00 4.91e+00  -1.7 3.12e+03    -  1.00e+00 1.56e-02h  7
#   91  1.6475199e+00 2.10e+01 7.55e+02  -1.7 9.22e+01  -4.0 1.00e+00 1.00e+00w  1
#   92  1.7690255e+00 3.95e+00 4.23e+02  -1.7 1.29e+02  -4.5 1.00e+00 1.00e+00w  1
#   93  6.4467231e+01 2.23e+02 5.55e+10  -1.7 3.10e+03  -4.1 1.00e+00 1.00e+00w  1
#   94  1.6197638e+00 6.15e+00 1.89e+02  -1.7 1.56e+05  -0.9 1.00e+00 5.00e-01h  1
#   95  1.6333757e+00 4.20e+00 3.31e+02  -1.7 2.04e+01  -1.4 1.00e+00 1.00e+00h  1
#   96  1.6311607e+00 1.52e-02 5.83e+01  -1.7 2.13e+00  -1.9 1.00e+00 1.00e+00h  1
#   97  1.6212895e+00 2.17e-01 2.87e+02  -1.7 1.08e+01  -2.3 1.00e+00 1.00e+00h  1
#   98  1.6100588e+00 2.18e+00 4.20e+02  -1.7 3.44e+01  -2.8 1.00e+00 1.00e+00h  1
#   99  1.6113049e+00 2.05e+00 3.24e+02  -1.7 6.07e+01  -3.3 1.00e+00 1.25e-01h  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100  1.6178842e+00 1.99e+00 7.00e+07  -1.7 2.00e+03  -3.8 1.00e+00 3.12e-02h  6
#  101  1.6178836e+00 6.84e-01 2.13e+10  -1.7 6.77e-03  12.5 1.00e+00 1.00e+00h  1
#  102  1.6178791e+00 2.90e-01 1.05e+10  -1.7 9.94e-03  12.0 1.00e+00 1.00e+00h  1
#  103  1.6178573e+00 3.65e-01 4.22e+09  -1.7 1.23e-02  11.5 1.00e+00 1.00e+00h  1
#  104  1.6177842e+00 4.12e-01 1.63e+09  -1.7 1.39e-02  11.1 1.00e+00 1.00e+00h  1
#  105  1.6177569e+00 2.41e-01 1.75e+09  -1.7 5.88e-03  11.5 1.00e+00 1.00e+00h  1
#  106  1.6176628e+00 1.73e-01 1.15e+09  -1.7 1.13e-02  11.0 1.00e+00 1.00e+00h  1
#  107  1.6060179e+00 3.71e-01 4.40e+20  -2.5 3.89e+03  10.5 1.00e+00 1.56e-02h  7
# WARNING: Problem in step computation; switching to emergency mode.
#  108r 1.6060179e+00 3.71e-01 9.99e+02  -0.4 0.00e+00  19.9 0.00e+00 0.00e+00R  1
#  109r 1.6051425e+00 9.49e-02 9.83e+02  -0.4 1.53e+03    -  1.56e-01 9.91e-04f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110  1.6025450e+00 1.14e+00 3.25e+06  -2.5 2.19e+04    -  1.00e+00 3.12e-02h  6
# WARNING: Problem in step computation; switching to emergency mode.
#  111r 1.6025450e+00 1.14e+00 9.99e+02   0.1 0.00e+00    -  0.00e+00 0.00e+00R  1
#  112r 1.6023660e+00 2.92e-01 9.86e+02   0.1 1.47e+03    -  7.78e-01 9.91e-04f  1
#  113  1.6026946e+00 2.92e-01 6.57e+04  -2.5 2.15e+04    -  1.00e+00 4.88e-04h 12
# WARNING: Problem in step computation; switching to emergency mode.
#  114r 1.6026946e+00 2.92e-01 9.99e+02  -0.5 0.00e+00    -  0.00e+00 0.00e+00R  1
#  115r 1.6020082e+00 7.38e-02 9.81e+02  -0.5 1.57e+03    -  1.20e-01 9.91e-04f  1
#  116  1.6021009e+00 7.38e-02 2.54e+10  -2.5 4.08e+05    -  1.00e+00 1.22e-04h 14
# WARNING: Problem in step computation; switching to emergency mode.
#  117r 1.6021009e+00 7.38e-02 9.99e+02  -1.1 0.00e+00    -  0.00e+00 0.00e+00R  1
#  118r 1.5990689e+00 2.30e-02 9.82e+02  -1.1 2.89e+03    -  2.06e-02 9.91e-04f  1
#  119  1.2947719e+00 8.18e+01 3.18e+02  -2.5 2.62e+03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120  1.2947719e+00 8.17e+01 1.37e+14  -2.5 1.40e-06  20.0 1.00e+00 1.00e+00h  1
#  121  1.2947719e+00 8.17e+01 2.74e+14  -2.5 8.38e-06  19.5 1.00e+00 1.00e+00h  1
#  122  1.2947719e+00 8.16e+01 4.10e+14  -2.5 3.77e-05  19.0 1.00e+00 1.00e+00h  1
#  123  1.2947719e+00 8.12e+01 5.46e+14  -2.5 1.51e-04  18.6 1.00e+00 1.00e+00h  1
#  124  1.2947719e+00 7.95e+01 6.79e+14  -2.5 5.61e-04  18.1 1.00e+00 1.00e+00h  1
#  125  1.2947719e+00 7.36e+01 8.00e+14  -2.5 1.98e-03  17.6 1.00e+00 1.00e+00h  1
#  126  1.2947719e+00 5.43e+01 8.84e+14  -2.5 6.58e-03  17.1 1.00e+00 1.00e+00h  1
#  127  1.2947719e+00 3.95e+01 8.61e+14  -2.5 1.92e-02  16.7 1.00e+00 1.00e+00h  1
#  128  1.2947719e+00 7.64e+01 3.59e+14  -2.5 4.13e-02  16.2 1.00e+00 1.00e+00H  1
#  129  1.2947719e+00 5.58e+01 2.06e+14  -2.5 4.81e-02  15.7 1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130  1.2947721e+00 5.65e+01 1.17e+14  -2.5 9.03e-02  15.2 1.00e+00 1.00e+00H  1
#  131  1.2947731e+00 4.06e+01 5.09e+13  -2.5 1.45e-01  14.7 1.00e+00 1.00e+00H  1
#  132  1.2947759e+00 4.07e+01 2.83e+13  -2.5 1.98e-01  14.3 1.00e+00 1.00e+00H  1
#  133r 1.2947759e+00 4.07e+01 9.99e+02   1.6 0.00e+00  13.8 0.00e+00 4.77e-07R 22
#  134r 1.2885779e+00 1.23e+01 9.74e+02   1.6 5.51e+04    -  3.71e-02 9.92e-04f  1
#  135  1.3002147e+00 3.09e+01 7.56e+01  -2.5 1.41e+03    -  1.00e+00 1.00e+00H  1
#  136  1.1552491e+00 3.44e+01 9.14e+00  -2.5 2.26e+03    -  1.00e+00 1.00e+00h  1
#  137  1.1552508e+00 1.14e+01 1.68e+12  -2.5 6.37e-02  13.3 1.00e+00 1.00e+00h  1
#  138  1.1552616e+00 1.00e+01 3.52e+11  -2.5 5.21e-02  12.8 1.00e+00 1.00e+00h  1
#  139  1.1553087e+00 5.25e+00 3.37e+11  -2.5 1.42e-01  12.4 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140  1.1579359e+00 5.25e+00 4.33e+19  -2.5 6.97e+06  11.9 1.00e+00 7.63e-06h 18
#  141  1.1689296e+00 5.27e+00 7.02e+27  -2.5 1.30e+04  11.4 1.00e+00 3.91e-03h  9
# WARNING: Problem in step computation; switching to emergency mode.
#  142r 1.1689296e+00 5.27e+00 9.99e+02   0.7 0.00e+00  19.2 0.00e+00 0.00e+00R  1
#  143r 1.1692581e+00 1.39e+00 9.96e+02   0.7 3.27e+04    -  2.73e-02 1.01e-03f  1
#  144  1.1717133e+00 1.37e+00 1.02e+07  -2.5 9.91e+04    -  1.00e+00 9.77e-04h 11
# WARNING: Problem in step computation; switching to emergency mode.
#  145r 1.1717133e+00 1.37e+00 9.99e+02   0.1 0.00e+00    -  0.00e+00 0.00e+00R  1
#  146r 1.1720408e+00 4.09e-01 9.93e+02   0.1 1.72e+04    -  1.96e-02 1.00e-03f  1
#  147  1.1719701e+00 5.21e-01 4.31e+00  -2.5 1.16e+04    -  1.00e+00 7.81e-03h  8
#  148  1.1720071e+00 5.21e-01 4.31e+00  -2.5 1.15e+04    -  1.00e+00 4.88e-04h 12
#  149  1.1720275e+00 5.21e-01 4.31e+00  -2.5 1.15e+04    -  1.00e+00 2.44e-04h 13
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150  1.1720381e+00 5.21e-01 4.31e+00  -2.5 1.15e+04    -  1.00e+00 1.22e-04h 14
#  151r 1.1720381e+00 5.21e-01 9.99e+02  -0.3 0.00e+00    -  0.00e+00 4.77e-07R 22
#  152r 1.1731003e+00 2.31e-01 9.95e+02  -0.3 6.75e+03    -  1.48e-02 9.92e-04f  1
#  153  1.1732024e+00 2.30e-01 4.32e+00  -2.5 1.20e+04    -  1.00e+00 9.77e-04h 11
#  154  1.1733237e+00 2.28e-01 4.32e+00  -2.5 1.20e+04    -  1.00e+00 9.77e-04h 11
#  155  1.1734639e+00 2.29e-01 4.32e+00  -2.5 1.20e+04    -  1.00e+00 9.77e-04h 11
#  156  1.1736229e+00 2.32e-01 4.31e+00  -2.5 1.20e+04    -  1.00e+00 9.77e-04h 11
#  157  1.1738006e+00 2.34e-01 4.31e+00  -2.5 1.19e+04    -  1.00e+00 9.77e-04h 11
#  158  1.1739969e+00 2.37e-01 4.30e+00  -2.5 1.19e+04    -  1.00e+00 9.77e-04h 11
#  159  1.1742117e+00 2.40e-01 4.30e+00  -2.5 1.19e+04    -  1.00e+00 9.77e-04h 11
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160  1.1744448e+00 2.42e-01 4.30e+00  -2.5 1.19e+04    -  1.00e+00 9.77e-04h 11
#  161  1.1746961e+00 2.45e-01 4.29e+00  -2.5 1.18e+04    -  1.00e+00 9.77e-04h 11
#  162  1.1749655e+00 2.47e-01 4.29e+00  -2.5 1.18e+04    -  1.00e+00 9.77e-04h 11
#  163  1.1397269e+01 3.39e+03 1.58e+04  -2.5 1.18e+04    -  1.00e+00 1.00e+00w  1
#  164  1.0457840e+01 4.00e+02 2.97e+03  -2.5 9.93e+02  -4.0 1.00e+00 1.00e+00w  1
#  165  1.2028801e+01 7.11e+01 9.83e+03  -2.5 4.40e+02  -3.6 1.00e+00 1.00e+00w  1
#  166  1.1752529e+00 2.50e-01 4.28e+00  -2.5 9.45e+03  -3.1 1.00e+00 9.77e-04h 10
#  167  1.1755582e+00 2.52e-01 4.28e+00  -2.5 1.18e+04    -  1.00e+00 9.77e-04h 11
#  168  1.1758812e+00 2.55e-01 4.27e+00  -2.5 1.18e+04    -  1.00e+00 9.77e-04h 11
#  169  1.1762218e+00 2.57e-01 4.27e+00  -2.5 1.17e+04    -  1.00e+00 9.77e-04h 11
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170  1.1765800e+00 2.60e-01 4.27e+00  -2.5 1.17e+04    -  1.00e+00 9.77e-04h 11
#  171  1.1769555e+00 2.62e-01 4.26e+00  -2.5 1.17e+04    -  1.00e+00 9.77e-04h 11
#  172  1.1773483e+00 2.65e-01 4.26e+00  -2.5 1.17e+04    -  1.00e+00 9.77e-04h 11
#  173  1.1777583e+00 2.67e-01 4.25e+00  -2.5 1.16e+04    -  1.00e+00 9.77e-04h 11
#  174  1.1781853e+00 2.70e-01 4.25e+00  -2.5 1.16e+04    -  1.00e+00 9.77e-04h 11
#  175  1.1786292e+00 2.72e-01 4.25e+00  -2.5 1.16e+04    -  1.00e+00 9.77e-04h 11
#  176  1.1170318e+01 3.27e+03 1.57e+04  -2.5 1.16e+04    -  1.00e+00 1.00e+00w  1
#  177  1.0263346e+01 3.69e+02 6.83e+03  -2.5 9.85e+02  -3.6 1.00e+00 1.00e+00w  1
#  178  1.1183790e+01 4.72e+01 8.37e+03  -2.5 3.07e+02  -3.2 1.00e+00 1.00e+00w  1
#  179  1.1790900e+00 2.74e-01 4.24e+00  -2.5 2.86e+02  -2.8 1.00e+00 9.77e-04h 10
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180  1.1795675e+00 2.77e-01 4.24e+00  -2.5 1.15e+04    -  1.00e+00 9.77e-04h 11
#  181  1.1800615e+00 2.79e-01 4.23e+00  -2.5 1.15e+04    -  1.00e+00 9.77e-04h 11
#  182  1.1805720e+00 2.82e-01 4.23e+00  -2.5 1.15e+04    -  1.00e+00 9.77e-04h 11
#  183  1.1838183e+00 2.69e-01 4.12e+07  -2.5 1.40e+06    -  1.00e+00 2.44e-04h 13
#  184  1.1838183e+00 2.63e-01 3.64e+11  -2.5 3.09e-06  17.1 1.00e+00 1.00e+00h  1
#  185  1.1838183e+00 2.25e-01 6.84e+11  -2.5 1.74e-05  16.6 1.00e+00 1.00e+00h  1
#  186  1.1838183e+00 1.71e-01 8.38e+11  -2.5 6.40e-05  16.1 1.00e+00 1.00e+00h  1
#  187  1.1838183e+00 2.15e-01 6.26e+11  -2.5 1.43e-04  15.6 1.00e+00 1.00e+00h  1
#  188  1.1838184e+00 2.28e-01 3.27e+11  -2.5 3.44e-05  16.1 1.00e+00 1.00e+00H  1
#  189  1.1838184e+00 2.20e-01 2.28e+11  -2.5 5.88e-05  15.6 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190  1.1838184e+00 2.24e-01 3.03e+11  -2.5 2.93e-05  16.0 1.00e+00 1.00e+00h  1
#  191  1.1838185e+00 2.11e-01 2.74e+11  -2.5 7.94e-05  15.5 1.00e+00 1.00e+00h  1
#  192  1.1838185e+00 1.97e-01 2.50e+11  -2.5 2.71e-05  16.0 1.00e+00 1.00e+00h  1
#  193  1.1838187e+00 1.61e-01 2.67e+11  -2.5 8.72e-05  15.5 1.00e+00 1.00e+00h  1
#  194  1.1838187e+00 1.63e-01 2.84e+11  -2.5 3.47e-05  15.9 1.00e+00 1.00e+00h  1
#  195  1.1838188e+00 1.73e-01 3.70e+12  -2.5 1.36e-03  15.4 1.00e+00 1.00e+00h  1
#  196  1.1838189e+00 1.77e-01 5.86e+12  -2.5 8.06e-04  15.9 1.00e+00 1.00e+00h  1
#  197  1.1838189e+00 1.79e-01 6.80e+12  -2.5 3.51e-04  16.3 1.00e+00 1.00e+00h  1
#  198  1.1838190e+00 1.86e-01 1.16e+13  -2.5 1.80e-03  15.8 1.00e+00 1.00e+00h  1
#  199  1.1838190e+00 1.88e-01 1.38e+13  -2.5 7.99e-04  16.2 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200  1.1838191e+00 1.95e-01 2.58e+13  -2.5 4.49e-03  15.8 1.00e+00 1.00e+00h  1
#  201  1.1838192e+00 1.97e-01 3.13e+13  -2.5 2.04e-03  16.2 1.00e+00 1.00e+00h  1
#  202  1.1838193e+00 2.03e-01 6.58e+13  -2.5 1.29e-02  15.7 1.00e+00 1.00e+00h  1
#  203  1.1838193e+00 2.04e-01 8.19e+13  -2.5 6.02e-03  16.1 1.00e+00 1.00e+00h  1
#  204  1.1838195e+00 2.09e-01 2.00e+14  -2.5 4.41e-02  15.7 1.00e+00 1.00e+00h  1
#  205  1.1838195e+00 2.20e-01 2.57e+14  -2.5 2.12e-02  16.1 1.00e+00 1.00e+00h  1
#  206r 1.1838195e+00 2.20e-01 9.99e+02  -0.7 0.00e+00  15.6 0.00e+00 4.77e-07R 22
#  207r 1.1870366e+00 3.04e-01 9.69e+02  -0.7 7.19e+03    -  1.37e-01 9.90e-04f  1
#  208r 1.1814339e+00 3.38e+00 9.42e+02  -0.7 3.35e+03    -  5.01e-03 5.48e-02f  1
#  209r 1.1920392e+00 3.57e+00 8.02e+02  -0.7 4.88e+02    -  1.56e-01 6.13e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210r 1.1982553e+00 3.39e+00 6.89e+02  -0.7 1.48e+02    -  1.35e-01 1.98e-01f  1
#  211r 1.1900720e+00 2.03e+00 3.95e+02  -0.7 3.26e+02    -  1.00e+00 3.11e-01f  1
#  212r 1.1842205e+00 2.66e-01 1.65e+00  -0.7 1.73e+02    -  1.00e+00 1.00e+00f  1
#  213r 1.1842206e+00 1.36e-02 4.34e+00  -2.1 6.78e+00    -  1.00e+00 9.50e-01f  1
#  214  1.1623367e+00 3.07e+00 3.20e+00  -2.5 8.89e+02    -  1.00e+00 5.00e-01h  2
#  215  1.1623367e+00 2.50e+00 1.31e+12  -2.5 9.78e-04  15.1 1.00e+00 1.00e+00h  1
#  216  1.1623367e+00 1.06e+00 9.01e+11  -2.5 2.01e-03  14.7 1.00e+00 1.00e+00h  1
#  217  1.1623367e+00 1.31e+00 5.66e+11  -2.5 3.79e-03  14.2 1.00e+00 1.00e+00h  1
#  218  1.1623368e+00 6.42e-01 1.63e+11  -2.5 3.98e-03  13.7 1.00e+00 1.00e+00H  1
#  219  1.1623370e+00 4.84e-01 6.78e+10  -2.5 5.00e-03  13.2 1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220  1.1623374e+00 3.57e-01 4.36e+10  -2.5 1.01e-02  12.7 1.00e+00 1.00e+00H  1
#  221  1.1623383e+00 2.88e-01 2.08e+10  -2.5 1.27e-02  12.3 1.00e+00 1.00e+00H  1
#  222  1.1623391e+00 2.68e-01 1.86e+10  -2.5 2.99e-02  11.8 1.00e+00 1.00e+00H  1
#  223  1.1623618e+00 3.43e-01 1.03e+10  -2.5 6.05e-02  11.3 1.00e+00 1.00e+00H  1
#  224  1.1625115e+00 5.79e-01 7.20e+09  -2.5 7.84e-02  10.8 1.00e+00 1.00e+00H  1
#  225  1.1630693e+00 5.78e-01 1.77e+17  -2.5 4.35e+03  10.4 1.00e+00 3.91e-03h  9
# WARNING: Problem in step computation; switching to emergency mode.
#  226r 1.1630693e+00 5.78e-01 9.99e+02  -0.2 0.00e+00  18.2 0.00e+00 0.00e+00R  1
#  227r 1.1634316e+00 1.82e-01 9.91e+02  -0.2 2.90e+03    -  1.38e-01 9.91e-04f  1
#  228  1.1624244e+00 3.12e-01 4.28e+00  -2.5 7.15e+03    -  1.00e+00 3.12e-02h  6
#  229  1.1624221e+00 3.15e-01 4.26e+00  -2.5 6.59e+03    -  1.00e+00 3.91e-03h  9
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230r 1.1624221e+00 3.15e-01 9.99e+02  -0.5 0.00e+00  19.7 0.00e+00 4.77e-07R 22
#  231r 1.1627942e+00 1.40e-01 9.93e+02  -0.5 1.41e+03    -  9.65e-02 9.90e-04f  1
#  232  1.1627833e+00 1.39e-01 4.38e+00  -2.5 5.79e+03    -  1.00e+00 7.81e-03h  8
#  233  1.1627920e+00 1.39e-01 4.37e+00  -2.5 5.67e+03    -  1.00e+00 1.95e-03h 10
#  234  1.1627934e+00 1.39e-01 4.37e+00  -2.5 5.64e+03    -  1.00e+00 2.44e-04h 13
#  235  1.1627938e+00 1.39e-01 4.37e+00  -2.5 5.64e+03    -  1.00e+00 6.10e-05h 15
#  236  1.1627939e+00 1.39e-01 4.37e+00  -2.5 5.64e+03    -  1.00e+00 3.05e-05h 16
#  237r 1.1627939e+00 1.39e-01 9.99e+02  -0.9 0.00e+00    -  0.00e+00 4.77e-07R 22
#  238r 1.1632680e+00 1.38e-01 9.96e+02  -0.9 1.32e+03    -  8.75e-02 9.90e-04f  1
#  239r 1.1728305e+00 4.00e-01 9.11e+02  -0.9 2.16e+02    -  9.89e-02 8.30e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240r 1.1708143e+00 3.44e-01 6.43e+02  -0.9 2.32e+01    -  8.92e-01 1.81e-01f  1
#  241r 1.1618966e+00 1.11e-02 7.97e-01  -0.9 1.41e+01    -  1.00e+00 1.00e+00f  1
#  242  1.1616612e+00 1.60e-02 2.91e+08  -2.5 4.59e+04    -  1.00e+00 3.91e-03h  9
#  243  1.1616612e+00 1.60e-02 2.57e+10  -3.8 1.45e-09  19.2 1.00e+00 1.00e+00h  1
#  244  1.1616612e+00 1.59e-02 5.13e+10  -3.8 8.71e-09  18.8 1.00e+00 1.00e+00h  1
#  245  1.1616612e+00 1.59e-02 7.69e+10  -3.8 3.92e-08  18.3 1.00e+00 1.00e+00h  1
#  246  1.1616612e+00 1.56e-02 1.02e+11  -3.8 1.56e-07  17.8 1.00e+00 1.00e+00h  1
#  247  1.1616612e+00 1.47e-02 1.26e+11  -3.8 5.77e-07  17.3 1.00e+00 1.00e+00h  1
#  248  1.1616612e+00 1.30e-02 1.45e+11  -3.8 1.99e-06  16.9 1.00e+00 1.00e+00h  1
#  249  1.1616612e+00 1.30e-02 1.62e+11  -3.8 8.36e-07  17.3 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  250  1.1616612e+00 1.31e-02 1.73e+11  -3.8 2.67e-06  16.8 1.00e+00 1.00e+00h  1
#  251  1.1616612e+00 1.30e-02 1.81e+11  -3.8 1.05e-06  17.2 1.00e+00 1.00e+00h  1
#  252  1.1616612e+00 1.29e-02 1.82e+11  -3.8 3.16e-06  16.8 1.00e+00 1.00e+00h  1
#  253  1.1616612e+00 1.29e-02 1.80e+11  -3.8 1.17e-06  17.2 1.00e+00 1.00e+00h  1
#  254  1.1616612e+00 1.26e-02 1.60e+11  -3.8 3.32e-06  16.7 1.00e+00 1.00e+00H  1
#  255  1.1616612e+00 1.24e-02 1.47e+11  -3.8 1.08e-06  17.1 1.00e+00 1.00e+00h  1
#  256  1.1616612e+00 1.41e-02 2.75e+11  -3.8 6.04e-06  16.7 1.00e+00 1.00e+00h  1
#  257  1.1616612e+00 1.52e-02 3.95e+11  -3.8 3.26e-06  17.1 1.00e+00 1.00e+00h  1
#  258  1.1616612e+00 1.86e-02 4.59e+12  -3.8 1.14e-04  16.6 1.00e+00 1.00e+00h  1
#  259  1.1616612e+00 1.94e-02 6.99e+12  -3.8 6.49e-05  17.0 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  260  1.1616612e+00 1.96e-02 8.02e+12  -3.8 2.79e-05  17.5 1.00e+00 1.00e+00h  1
#  261  1.1616612e+00 1.97e-02 1.30e+13  -3.8 1.36e-04  17.0 1.00e+00 1.00e+00h  1
#  262  1.1616612e+00 1.96e-02 1.53e+13  -3.8 5.98e-05  17.4 1.00e+00 1.00e+00h  1
#  263  1.1616612e+00 1.87e-02 2.69e+13  -3.8 3.17e-04  16.9 1.00e+00 1.00e+00h  1
#  264  1.1616612e+00 1.82e-02 3.22e+13  -3.8 1.42e-04  17.4 1.00e+00 1.00e+00h  1
#  265  1.1616612e+00 1.62e-02 6.28e+13  -3.8 8.31e-04  16.9 1.00e+00 1.00e+00h  1
#  266  1.1616612e+00 1.53e-02 7.69e+13  -3.8 3.81e-04  17.3 1.00e+00 1.00e+00h  1
#  267  1.1616612e+00 1.94e-02 1.71e+14  -3.8 2.54e-03  16.8 1.00e+00 1.00e+00h  1
#  268  1.1616612e+00 2.44e-02 2.15e+14  -3.8 1.20e-03  17.3 1.00e+00 1.00e+00h  1
#  269r 1.1616612e+00 2.44e-02 9.99e+02  -1.6 0.00e+00  16.8 0.00e+00 4.77e-07R 22
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  270r 1.1616450e+00 6.14e-03 9.71e+02  -1.6 2.03e+02    -  5.89e-02 9.91e-04f  1
#  271  1.1619179e+00 6.05e-03 4.34e+00  -3.8 5.52e+02    -  1.00e+00 1.56e-02h  7
#  272  1.1620530e+00 6.01e-03 4.30e+00  -3.8 5.31e+02    -  1.00e+00 7.81e-03h  8
#  273  1.1621880e+00 5.96e-03 4.27e+00  -3.8 5.21e+02    -  1.00e+00 7.81e-03h  8
#  274  1.1622550e+00 5.94e-03 4.25e+00  -3.8 5.11e+02    -  1.00e+00 3.91e-03h  9
#  275  1.1622550e+00 5.90e-03 8.25e+09  -3.8 4.14e-07  16.3 1.00e+00 1.00e+00h  1
#  276  1.1622550e+00 6.05e-03 1.01e+10  -3.8 1.52e-06  15.8 1.00e+00 1.00e+00h  1
#  277  1.1622550e+00 6.15e-03 8.49e+09  -3.8 3.84e-06  15.3 1.00e+00 1.00e+00h  1
#  278  1.1622550e+00 6.01e-03 5.62e+09  -3.8 7.62e-06  14.9 1.00e+00 1.00e+00h  1
#  279  1.1622550e+00 5.12e-03 5.13e+09  -3.8 2.09e-05  14.4 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  280  1.1622550e+00 5.31e-03 1.65e+09  -3.8 3.37e-05  13.9 1.00e+00 1.00e+00H  1
#  281  1.1622550e+00 4.58e-03 1.23e+09  -3.8 4.81e-05  13.4 1.00e+00 1.00e+00H  1
#  282  1.1622550e+00 3.60e-03 4.94e+08  -3.8 6.19e-05  13.0 1.00e+00 1.00e+00H  1
#  283  1.1622552e+00 3.91e-03 4.18e+08  -3.8 1.44e-04  12.5 1.00e+00 1.00e+00H  1
#  284  1.1622556e+00 3.48e-03 3.57e+08  -3.8 3.70e-04  12.0 1.00e+00 1.00e+00H  1
#  285  1.1622573e+00 6.58e-03 1.95e+08  -3.8 8.85e-04  11.5 1.00e+00 1.00e+00H  1
#  286  1.1622626e+00 8.22e-03 4.41e+07  -3.8 8.33e-04  11.1 1.00e+00 1.00e+00H  1
#  287  1.1622778e+00 5.11e-03 4.54e+07  -3.8 1.21e-03  10.6 1.00e+00 1.00e+00h  1
#  288  1.1623211e+00 5.04e-03 4.46e+07  -3.8 3.57e-03  10.1 1.00e+00 1.00e+00h  1
#  289  1.1624358e+00 8.02e-03 3.88e+07  -3.8 9.33e-03   9.6 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  290  1.1626605e+00 1.88e-02 2.42e+07  -3.8 1.75e-02   9.1 1.00e+00 1.00e+00h  1
#  291  1.1629014e+00 2.14e-02 5.69e+06  -3.8 1.23e-02   8.7 1.00e+00 1.00e+00h  1
#  292  1.1630483e+00 1.22e-02 2.58e+06  -3.8 1.67e-02   8.2 1.00e+00 1.00e+00h  1
#  293  1.1627766e+00 9.76e-04 1.15e+06  -3.8 2.13e-02   7.7 1.00e+00 1.00e+00H  1
#  294  1.1625726e+00 1.73e-03 2.95e+05  -3.8 1.72e-02   7.2 1.00e+00 1.00e+00h  1
#  295  1.1625700e+00 1.11e-03 2.20e+05  -3.8 4.49e-02   6.8 1.00e+00 1.00e+00H  1
#  296  1.1624995e+00 2.27e-03 1.38e+05  -3.8 7.25e-02   6.3 1.00e+00 1.00e+00h  1
#  297  1.1626727e+00 1.42e-03 2.78e+04  -3.8 6.73e-02   5.8 1.00e+00 1.00e+00H  1
#  298  1.1630609e+00 4.36e-04 1.51e+04  -3.8 4.93e-02   5.3 1.00e+00 1.00e+00H  1
#  299  1.1632649e+00 1.00e-04 2.28e+03  -3.8 4.49e-02   4.8 1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  300  1.1634242e+00 5.81e-05 4.76e+02  -3.8 2.20e-02   4.4 1.00e+00 1.00e+00H  1
#  301  1.1633209e+00 5.82e-05 2.91e+02  -3.8 4.57e-02   3.9 1.00e+00 1.00e+00H  1
#  302  1.1631038e+00 6.81e-05 1.73e+02  -3.8 8.68e-02   3.4 1.00e+00 1.00e+00H  1
#  303  1.1627416e+00 1.35e-04 8.45e+01  -3.8 9.71e-02   2.9 1.00e+00 1.00e+00h  1
#  304  1.1623984e+00 1.29e-04 2.11e+01  -3.8 7.26e-02   2.5 1.00e+00 1.00e+00h  1
#  305  1.1620395e+00 2.12e-04 1.24e+01  -3.8 1.28e-01   2.0 1.00e+00 1.00e+00h  1
#  306  1.1617268e+00 2.14e-04 8.78e+00  -3.8 1.70e-01   1.5 1.00e+00 1.00e+00h  1
#  307  1.1628802e+00 4.53e-05 3.49e+00  -3.8 3.20e-01   1.0 1.00e+00 1.00e+00H  1
#  308  1.1628070e+00 2.93e-05 6.25e+00  -3.8 2.34e-01   0.6 1.00e+00 1.00e+00H  1
#  309  1.1626544e+00 1.61e-04 2.25e+01  -3.8 7.13e-01   0.1 1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  310  1.1626660e+00 1.60e-04 2.12e+01  -3.8 2.15e+00  -0.4 1.00e+00 6.25e-02h  5
#  311  1.1626672e+00 1.60e-04 2.12e+01  -3.8 6.76e+00  -0.9 1.00e+00 1.95e-03h 10
#  312  1.1626675e+00 1.60e-04 2.12e+01  -3.8 2.41e+01  -1.4 1.00e+00 2.44e-04h 13
#  313  1.1626442e+00 3.18e-04 2.11e+01  -3.8 2.35e+02  -1.8 1.00e+00 1.95e-03h 10
#  314  1.1626446e+00 3.18e-04 2.11e+01  -3.8 2.80e+01  -1.4 1.00e+00 2.44e-04h 13
#  315  1.1626366e+00 3.33e-04 2.11e+01  -3.8 4.76e+02  -1.9 1.00e+00 2.44e-04h 13
#  316  1.1626371e+00 3.33e-04 2.11e+01  -3.8 3.29e+01  -1.5 1.00e+00 2.44e-04h 13
#  317  1.1626351e+00 3.34e-04 2.11e+01  -3.8 1.13e+04  -1.9 1.00e+00 1.91e-06h 20
#  318  1.1626353e+00 3.34e-04 2.11e+01  -3.8 3.91e+01  -1.5 1.00e+00 1.22e-04h 14
#  319  1.1626363e+00 3.33e-04 2.10e+01  -3.8 1.13e+01  -1.1 1.00e+00 9.77e-04h 11
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  320  1.1851843e+00 2.37e+00 5.92e+03  -3.8 4.71e+01  -1.6 1.00e+00 1.00e+00w  1
#  321  1.3331998e+00 7.01e+00 3.58e+04  -3.8 6.39e+01  -2.0 1.00e+00 1.00e+00w  1
#  322  1.3428983e+00 3.47e-02 4.35e+02  -3.8 3.56e+00  -0.7 1.00e+00 1.00e+00w  1
#  323  1.1626365e+00 3.33e-04 2.10e+01  -3.8 6.82e+00  -1.2 1.00e+00 1.22e-04h 13
#  324  1.1626365e+00 3.33e-04 2.10e+01  -3.8 7.22e+01  -1.7 1.00e+00 6.10e-05h 15
#  325  1.1626372e+00 3.33e-04 2.10e+01  -3.8 1.70e+01  -1.2 1.00e+00 4.88e-04h 12
#  326  1.1626372e+00 3.33e-04 2.10e+01  -3.8 9.35e+01  -1.7 1.00e+00 1.22e-04h 14
#  327  1.1626379e+00 3.33e-04 2.10e+01  -3.8 1.97e+01  -1.3 1.00e+00 4.88e-04h 12
#  328  1.1626378e+00 3.33e-04 2.10e+01  -3.8 1.28e+02  -1.8 1.00e+00 3.05e-05h 16
#  329  1.1626386e+00 3.33e-04 2.10e+01  -3.8 2.28e+01  -1.3 1.00e+00 4.88e-04h 12
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  330  1.1626384e+00 3.33e-04 2.10e+01  -3.8 1.91e+02  -1.8 1.00e+00 3.05e-05h 16
#  331  1.1626388e+00 3.33e-04 2.10e+01  -3.8 2.65e+01  -1.4 1.00e+00 2.44e-04h 13
#  332  1.1626382e+00 3.33e-04 2.10e+01  -3.8 3.47e+02  -1.9 1.00e+00 3.05e-05h 16
#  333  1.1750578e+00 1.22e+00 2.55e+03  -3.8 3.12e+01  -1.4 1.00e+00 1.00e+00w  1
#  334  1.3108210e+00 8.30e+00 4.06e+04  -3.8 9.22e+01  -1.9 1.00e+00 1.00e+00w  1
#  335  1.3548125e+00 6.36e-01 2.02e+03  -3.8 1.78e+01  -1.5 1.00e+00 1.00e+00w  1
#  336  1.1626386e+00 3.33e-04 2.10e+01  -3.8 4.20e+01  -2.0 1.00e+00 2.44e-04h 12
#  337  1.1626388e+00 3.33e-04 2.10e+01  -3.8 4.42e+01  -1.5 1.00e+00 1.22e-04h 14
#  338  1.1626399e+00 3.33e-04 2.10e+01  -3.8 1.24e+01  -1.1 1.00e+00 9.77e-04h 11
#  339  1.1626401e+00 3.33e-04 2.10e+01  -3.8 5.37e+01  -1.6 1.00e+00 1.22e-04h 14
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  340  1.1626413e+00 3.32e-04 2.09e+01  -3.8 1.42e+01  -1.2 1.00e+00 9.77e-04h 11
#  341  1.1626414e+00 3.32e-04 2.09e+01  -3.8 6.67e+01  -1.6 1.00e+00 6.10e-05h 15
#  342  1.1626427e+00 3.32e-04 2.09e+01  -3.8 1.63e+01  -1.2 1.00e+00 9.77e-04h 11
#  343  1.1626427e+00 3.32e-04 2.09e+01  -3.8 8.53e+01  -1.7 1.00e+00 6.10e-05h 15
#  344  1.1626434e+00 3.32e-04 2.09e+01  -3.8 1.87e+01  -1.3 1.00e+00 4.88e-04h 12
#  345  1.1626434e+00 3.32e-04 2.09e+01  -3.8 1.14e+02  -1.7 1.00e+00 6.10e-05h 15
#  346  1.1699817e+00 6.57e-01 1.19e+03  -3.8 2.17e+01  -1.3 1.00e+00 1.00e+00w  1
#  347  1.2632753e+00 6.13e+00 2.68e+04  -3.8 8.05e+01  -1.8 1.00e+00 1.00e+00w  1
#  348  1.2961796e+00 3.74e-01 2.01e+03  -3.8 1.43e+01  -1.4 1.00e+00 1.00e+00w  1
#  349  1.1626441e+00 3.32e-04 2.09e+01  -3.8 3.62e+01  -1.8 1.00e+00 4.88e-04h 11
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  350  1.1626442e+00 3.32e-04 2.09e+01  -3.8 2.95e+01  -1.4 1.00e+00 1.53e-05h 17
#  351  1.1626434e+00 3.32e-04 2.09e+01  -3.8 6.88e+02  -1.9 1.00e+00 1.53e-05h 17
#  352  1.1626439e+00 3.32e-04 2.09e+01  -3.8 3.48e+01  -1.5 1.00e+00 2.44e-04h 13
#  353  1.1626441e+00 3.32e-04 2.09e+01  -3.8 1.04e+01  -1.0 1.00e+00 2.44e-04h 13
#  354  1.1626442e+00 3.32e-04 2.09e+01  -3.8 4.15e+01  -1.5 1.00e+00 3.05e-05h 16
#  355  1.1626442e+00 3.32e-04 2.09e+01  -3.8 1.18e+01  -1.1 1.00e+00 1.53e-05h 17
#  356r 1.1626442e+00 3.32e-04 9.99e+02  -3.5 0.00e+00  -1.6 0.00e+00 4.77e-07R 22
#  357r 1.1626541e+00 8.68e-05 9.99e+02  -3.5 7.07e+02    -  4.37e-02 9.90e-04f  1
#  358  1.1626544e+00 8.68e-05 4.42e+00  -3.8 5.47e+02    -  1.00e+00 1.53e-05h 17
#  359r 1.1626544e+00 8.68e-05 9.98e+02  -3.8 0.00e+00    -  0.00e+00 4.77e-07R 22
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  360r 1.1626815e+00 7.61e-05 9.98e+02  -3.8 1.07e+03    -  1.85e-02 1.72e-03f  1
#  361  1.1626852e+00 7.58e-05 4.42e+00  -3.8 5.46e+02    -  1.00e+00 2.44e-04h 13
#  362  1.1626890e+00 7.56e-05 4.42e+00  -3.8 5.46e+02    -  1.00e+00 2.44e-04h 13
#  363  1.1626928e+00 7.54e-05 4.42e+00  -3.8 5.46e+02    -  1.00e+00 2.44e-04h 13
#  364  1.1626966e+00 7.52e-05 4.42e+00  -3.8 5.45e+02    -  1.00e+00 2.44e-04h 13
#  365  1.1627003e+00 7.50e-05 4.42e+00  -3.8 5.45e+02    -  1.00e+00 2.44e-04h 13
#  366  1.1627041e+00 7.48e-05 4.41e+00  -3.8 5.45e+02    -  1.00e+00 2.44e-04h 13
#  367  1.1627079e+00 7.46e-05 4.41e+00  -3.8 5.44e+02    -  1.00e+00 2.44e-04h 13
#  368  1.1627117e+00 7.44e-05 4.41e+00  -3.8 5.44e+02    -  1.00e+00 2.44e-04h 13
#  369  1.1627155e+00 7.42e-05 4.41e+00  -3.8 5.44e+02    -  1.00e+00 2.44e-04h 13
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  370  1.1627192e+00 7.39e-05 4.41e+00  -3.8 5.43e+02    -  1.00e+00 2.44e-04h 13
#  371  1.1993659e+00 5.88e+00 9.40e+00  -3.8 5.43e+02    -  1.00e+00 1.00e+00w  1
#  372  1.1998987e+00 5.93e-03 7.86e+00  -3.8 1.70e+00  -2.1 1.00e+00 1.00e+00w  1
#  373  1.1999723e+00 3.41e-03 3.93e+00  -3.8 1.44e+00  -2.5 1.00e+00 1.00e+00w  1
#  374  1.1627230e+00 7.37e-05 4.41e+00  -3.8 4.21e+00  -3.0 1.00e+00 2.44e-04h 12
#  375  1.1627268e+00 7.35e-05 4.41e+00  -3.8 5.43e+02    -  1.00e+00 2.44e-04h 13
#  376  1.1627306e+00 7.33e-05 4.41e+00  -3.8 5.42e+02    -  1.00e+00 2.44e-04h 13
#  377  1.1627324e+00 7.33e-05 4.41e+00  -3.8 5.42e+02    -  1.00e+00 1.22e-04h 14
#  378  1.1627343e+00 7.32e-05 4.41e+00  -3.8 5.42e+02    -  1.00e+00 1.22e-04h 14
#  379  1.1627404e+00 7.30e-05 1.11e+05  -3.8 5.90e+02    -  1.00e+00 2.44e-04h 13
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  380  1.1627404e+00 2.39e-05 2.59e+06  -5.7 3.78e-07  12.8 1.00e+00 1.00e+00h  1
#  381  1.1627404e+00 2.39e-05 2.88e+06  -5.7 1.57e-07  13.3 1.00e+00 1.00e+00h  1
#  382  1.1627404e+00 2.39e-05 2.95e+06  -5.7 6.05e-08  13.7 1.00e+00 1.00e+00h  1
#  383  1.1627404e+00 2.39e-05 3.01e+06  -5.7 1.85e-07  13.2 1.00e+00 1.00e+00h  1
#  384  1.1627404e+00 2.39e-05 3.51e+06  -5.7 8.09e-08  13.6 1.00e+00 1.00e+00h  1
#  385  1.1627404e+00 2.39e-05 6.12e+06  -5.7 4.23e-07  13.2 1.00e+00 1.00e+00h  1
#  386  1.1627404e+00 2.39e-05 7.28e+06  -5.7 1.89e-07  13.6 1.00e+00 1.00e+00h  1
#  387  1.1627404e+00 2.39e-05 1.40e+07  -5.7 1.09e-06  13.1 1.00e+00 1.00e+00h  1
#  388  1.1627404e+00 2.39e-05 1.70e+07  -5.7 4.97e-07  13.5 1.00e+00 1.00e+00h  1
#  389  1.1627404e+00 2.39e-05 3.70e+07  -5.7 3.24e-06  13.1 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  390  1.1627404e+00 2.39e-05 4.63e+07  -5.7 1.52e-06  13.5 1.00e+00 1.00e+00h  1
#  391  1.1627404e+00 2.39e-05 1.18e+08  -5.7 1.16e-05  13.0 1.00e+00 1.00e+00h  1
#  392  1.1627404e+00 2.39e-05 1.52e+08  -5.7 5.63e-06  13.4 1.00e+00 1.00e+00h  1
#  393  1.1627404e+00 3.90e-05 4.80e+08  -5.7 5.32e-05  13.0 1.00e+00 1.00e+00h  1
#  394  1.1627404e+00 5.24e-05 6.45e+08  -5.7 2.68e-05  13.4 1.00e+00 1.00e+00h  1
#  395  1.1627404e+00 2.26e-04 2.78e+09  -5.7 3.46e-04  12.9 1.00e+00 1.00e+00h  1
#  396  1.1627404e+00 3.17e-04 3.90e+09  -5.7 1.82e-04  13.3 1.00e+00 1.00e+00h  1
#  397  1.1627404e+00 2.33e-03 2.87e+10  -5.7 4.02e-03  12.9 1.00e+00 1.00e+00h  1
#  398  1.1627404e+00 3.44e-03 4.24e+10  -5.7 2.23e-03  13.3 1.00e+00 1.00e+00h  1
#  399  1.1627404e+00 1.22e-01 1.50e+12  -5.7 2.38e-01  12.8 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  400r 1.1627404e+00 1.22e-01 9.99e+02  -0.9 0.00e+00  13.2 0.00e+00 4.77e-07R 22
#  401r 1.1532868e+00 6.11e-02 9.66e+02  -0.9 5.25e+01    -  2.85e-01 2.33e-03f  1
#  402  1.1533001e+00 6.11e-02 4.41e+00  -5.7 3.40e+04    -  1.00e+00 1.22e-04h 14
#  403r 1.1533001e+00 6.11e-02 9.99e+02  -1.2 0.00e+00    -  0.00e+00 4.77e-07R 22
#  404r 1.1505689e+00 3.81e-02 9.77e+02  -1.2 1.78e+01    -  1.36e-01 2.60e-03f  1
#  405  1.1505724e+00 3.81e-02 4.41e+00  -5.7 9.91e+03    -  1.00e+00 6.10e-05h 15
#  406  1.1505760e+00 3.80e-02 4.41e+00  -5.7 9.91e+03    -  1.00e+00 6.10e-05h 15
#  407  1.1505779e+00 3.80e-02 4.41e+00  -5.7 9.91e+03    -  1.00e+00 3.05e-05h 16
#  408  1.1505797e+00 3.80e-02 4.41e+00  -5.7 9.91e+03    -  1.00e+00 3.05e-05h 16
#  409  1.1505816e+00 3.80e-02 4.41e+00  -5.7 9.90e+03    -  1.00e+00 3.05e-05h 16
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  410  1.1505835e+00 3.80e-02 4.41e+00  -5.7 9.90e+03    -  1.00e+00 3.05e-05h 16
#  411  1.1505854e+00 3.80e-02 4.41e+00  -5.7 9.90e+03    -  1.00e+00 3.05e-05h 16
#  412  1.1505874e+00 3.80e-02 4.41e+00  -5.7 9.90e+03    -  1.00e+00 3.05e-05h 16
#  413  1.1505894e+00 3.80e-02 4.41e+00  -5.7 9.90e+03    -  1.00e+00 3.05e-05h 16
#  414  1.1505914e+00 3.80e-02 4.41e+00  -5.7 9.90e+03    -  1.00e+00 3.05e-05h 16
#  415  1.4658659e+01 9.05e+01 4.26e+04  -5.7 9.89e+03    -  1.00e+00 1.00e+00w  1
#  416  1.4658640e+01 1.04e+01 2.15e+12  -5.7 2.18e-01  12.8 1.00e+00 1.00e+00w  1
#  417  1.4658579e+01 3.24e+02 3.99e+13  -5.7 8.95e-01  12.3 1.00e+00 1.00e+00w  1
#  418  1.1505934e+00 3.80e-02 4.41e+00  -5.7 2.52e-01  13.6 1.00e+00 3.05e-05h 15
#  419  1.1505955e+00 3.80e-02 4.41e+00  -5.7 9.89e+03    -  1.00e+00 3.05e-05h 16
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  420  1.1505976e+00 3.80e-02 4.41e+00  -5.7 9.89e+03    -  1.00e+00 3.05e-05h 16
#  421  1.1505997e+00 3.80e-02 4.41e+00  -5.7 9.89e+03    -  1.00e+00 3.05e-05h 16
#  422  1.1506018e+00 3.80e-02 4.41e+00  -5.7 9.89e+03    -  1.00e+00 3.05e-05h 16
#  423  1.1506040e+00 3.80e-02 4.41e+00  -5.7 9.89e+03    -  1.00e+00 3.05e-05h 16
#  424  1.1506062e+00 3.80e-02 4.41e+00  -5.7 9.89e+03    -  1.00e+00 3.05e-05h 16
#  425  1.1506084e+00 3.80e-02 4.41e+00  -5.7 9.88e+03    -  1.00e+00 3.05e-05h 16
#  426  1.1506106e+00 3.80e-02 4.41e+00  -5.7 9.88e+03    -  1.00e+00 3.05e-05h 16
#  427  1.1506129e+00 3.80e-02 4.41e+00  -5.7 9.88e+03    -  1.00e+00 3.05e-05h 16
#  428  1.4641549e+01 9.01e+01 4.26e+04  -5.7 9.88e+03    -  1.00e+00 1.00e+00w  1
#  429  1.4641535e+01 1.19e+01 4.09e+12  -5.7 1.97e-01  13.1 1.00e+00 1.00e+00w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  430  1.4641516e+01 9.72e+02 1.74e+14  -5.7 1.23e+00  12.6 1.00e+00 1.00e+00w  1
#  431  1.1506151e+00 3.80e-02 4.41e+00  -5.7 7.46e-01  14.0 1.00e+00 3.05e-05h 15
#  432  1.1506175e+00 3.80e-02 4.41e+00  -5.7 9.88e+03    -  1.00e+00 3.05e-05h 16
#  433  1.1506198e+00 3.80e-02 4.41e+00  -5.7 9.88e+03    -  1.00e+00 3.05e-05h 16
#  434  1.1506221e+00 3.80e-02 4.41e+00  -5.7 9.87e+03    -  1.00e+00 3.05e-05h 16
#  435  1.1506245e+00 3.80e-02 4.41e+00  -5.7 9.87e+03    -  1.00e+00 3.05e-05h 16
#  436  1.1506269e+00 3.80e-02 4.41e+00  -5.7 9.87e+03    -  1.00e+00 3.05e-05h 16
#  437  1.1506294e+00 3.80e-02 4.41e+00  -5.7 9.87e+03    -  1.00e+00 3.05e-05h 16
#  438  1.1506318e+00 3.80e-02 4.41e+00  -5.7 9.87e+03    -  1.00e+00 3.05e-05h 16
#  439  1.1506343e+00 3.80e-02 4.41e+00  -5.7 9.87e+03    -  1.00e+00 3.05e-05h 16
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  440  1.1506368e+00 3.80e-02 4.41e+00  -5.7 9.86e+03    -  1.00e+00 3.05e-05h 16
#  441  1.4624470e+01 8.97e+01 4.26e+04  -5.7 9.86e+03    -  1.00e+00 1.00e+00w  1
#  442  1.4624461e+01 1.44e+01 7.35e+12  -5.7 1.58e-01  13.5 1.00e+00 1.00e+00w  1
#  443  1.4624454e+01 6.67e+02 1.36e+14  -5.7 1.11e+00  13.0 1.00e+00 1.00e+00w  1
#  444  1.1506393e+00 3.80e-02 4.41e+00  -5.7 7.85e+05  12.5 1.00e+00 3.05e-05h 15
#  445  1.1506419e+00 3.80e-02 4.41e+00  -5.7 9.86e+03    -  1.00e+00 3.05e-05h 16
#  446  1.1506444e+00 3.80e-02 4.41e+00  -5.7 9.86e+03    -  1.00e+00 3.05e-05h 16
#  447  1.1506470e+00 3.80e-02 4.41e+00  -5.7 9.86e+03    -  1.00e+00 3.05e-05h 16
#  448  1.1506497e+00 3.80e-02 4.41e+00  -5.7 9.86e+03    -  1.00e+00 3.05e-05h 16
#  449  1.1506523e+00 3.80e-02 4.41e+00  -5.7 9.86e+03    -  1.00e+00 3.05e-05h 16
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  450  1.1506550e+00 3.80e-02 4.41e+00  -5.7 9.85e+03    -  1.00e+00 3.05e-05h 16
#  451  1.1506577e+00 3.80e-02 4.41e+00  -5.7 9.85e+03    -  1.00e+00 3.05e-05h 16
#  452  1.1506604e+00 3.80e-02 4.41e+00  -5.7 9.85e+03    -  1.00e+00 3.05e-05h 16
#  453  1.1506632e+00 3.80e-02 4.41e+00  -5.7 9.85e+03    -  1.00e+00 3.05e-05h 16
#  454  1.4607425e+01 8.93e+01 4.25e+04  -5.7 9.85e+03    -  1.00e+00 1.00e+00w  1
#  455  1.4607362e+01 1.06e+01 1.47e+12  -5.7 2.32e-01  12.1 1.00e+00 1.00e+00w  1
#  456  1.4607331e+01 5.48e+00 4.71e+11  -5.7 9.76e-02  12.5 1.00e+00 1.00e+00w  1
#  457  1.1506659e+00 3.80e-02 4.41e+00  -5.7 3.37e-01  12.0 1.00e+00 3.05e-05h 15
#  458  1.1506687e+00 3.80e-02 4.41e+00  -5.7 9.85e+03    -  1.00e+00 3.05e-05h 16
#  459  1.1506715e+00 3.80e-02 4.41e+00  -5.7 9.84e+03    -  1.00e+00 3.05e-05h 16
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  460  1.1506744e+00 3.80e-02 4.41e+00  -5.7 9.84e+03    -  1.00e+00 3.05e-05h 16
#  461  1.1506773e+00 3.80e-02 4.41e+00  -5.7 9.84e+03    -  1.00e+00 3.05e-05h 16
#  462  1.1506801e+00 3.80e-02 4.41e+00  -5.7 9.84e+03    -  1.00e+00 3.05e-05h 16
#  463  1.1506831e+00 3.80e-02 4.41e+00  -5.7 9.84e+03    -  1.00e+00 3.05e-05h 16
#  464  1.1506860e+00 3.80e-02 4.40e+00  -5.7 9.84e+03    -  1.00e+00 3.05e-05h 16
#  465  1.1506890e+00 3.80e-02 4.40e+00  -5.7 9.84e+03    -  1.00e+00 3.05e-05h 16
#  466  1.1506920e+00 3.80e-02 4.40e+00  -5.7 9.83e+03    -  1.00e+00 3.05e-05h 16
#  467  1.4590412e+01 8.89e+01 4.25e+04  -5.7 9.83e+03    -  1.00e+00 1.00e+00w  1
#  468  1.4590126e+01 9.83e+00 9.47e+11  -5.7 3.69e-01  11.5 1.00e+00 1.00e+00w  1
#  469  1.4589925e+01 4.32e+00 1.92e+11  -5.7 2.11e-01  12.0 1.00e+00 1.00e+00w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  470  1.1506950e+00 3.80e-02 4.40e+00  -5.7 9.70e-01  11.5 1.00e+00 3.05e-05h 15
#  471  1.1506980e+00 3.80e-02 4.40e+00  -5.7 9.83e+03    -  1.00e+00 3.05e-05h 16
#  472  1.1507011e+00 3.80e-02 4.40e+00  -5.7 9.83e+03    -  1.00e+00 3.05e-05h 16
#  473  1.1507042e+00 3.80e-02 4.40e+00  -5.7 9.83e+03    -  1.00e+00 3.05e-05h 16
#  474  1.1507073e+00 3.80e-02 4.40e+00  -5.7 9.83e+03    -  1.00e+00 3.05e-05h 16
#  475  1.1507104e+00 3.80e-02 4.40e+00  -5.7 9.82e+03    -  1.00e+00 3.05e-05h 16
#  476  1.1507136e+00 3.80e-02 4.40e+00  -5.7 9.82e+03    -  1.00e+00 3.05e-05h 16
#  477  1.1507168e+00 3.80e-02 4.40e+00  -5.7 9.82e+03    -  1.00e+00 3.05e-05h 16
#  478  1.1507200e+00 3.80e-02 4.40e+00  -5.7 9.82e+03    -  1.00e+00 3.05e-05h 16
#  479  1.1507232e+00 3.80e-02 4.40e+00  -5.7 9.82e+03    -  1.00e+00 3.05e-05h 16
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  480  1.4573431e+01 8.85e+01 4.24e+04  -5.7 9.82e+03    -  1.00e+00 1.00e+00w  1
#  481  1.4572273e+01 1.46e+01 7.01e+11  -5.7 5.28e-01  11.0 1.00e+00 1.00e+00w  1
#  482  1.4571271e+01 4.58e+00 1.73e+11  -5.7 3.33e-01  11.4 1.00e+00 1.00e+00w  1
#  483  1.1507265e+00 3.80e-02 4.40e+00  -5.7 1.85e+05  11.0 1.00e+00 3.05e-05h 15
#  484  1.1507298e+00 3.80e-02 4.40e+00  -5.7 9.82e+03    -  1.00e+00 3.05e-05h 16
#  485  1.1507331e+00 3.80e-02 4.40e+00  -5.7 9.81e+03    -  1.00e+00 3.05e-05h 16
#  486  1.1507364e+00 3.80e-02 4.40e+00  -5.7 9.81e+03    -  1.00e+00 3.05e-05h 16
#  487  1.1507397e+00 3.80e-02 4.40e+00  -5.7 9.81e+03    -  1.00e+00 3.05e-05h 16
#  488  1.1507431e+00 3.80e-02 4.40e+00  -5.7 9.81e+03    -  1.00e+00 3.05e-05h 16
#  489  1.1507465e+00 3.80e-02 4.40e+00  -5.7 9.81e+03    -  1.00e+00 3.05e-05h 16
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  490  1.1507500e+00 3.80e-02 4.40e+00  -5.7 9.81e+03    -  1.00e+00 3.05e-05h 16
#  491  1.1507534e+00 3.80e-02 4.40e+00  -5.7 9.80e+03    -  1.00e+00 3.05e-05h 16
#  492  1.1507569e+00 3.80e-02 4.40e+00  -5.7 9.80e+03    -  1.00e+00 3.05e-05h 16
#  493  1.4556482e+01 8.82e+01 4.24e+04  -5.7 9.80e+03    -  1.00e+00 1.00e+00w  1
#  494  1.4552314e+01 3.78e+01 4.14e+11  -5.7 7.49e-01  10.5 1.00e+00 1.00e+00w  1
#  495  1.4544901e+01 2.14e+01 1.40e+11  -5.7 4.36e-01  10.9 1.00e+00 1.00e+00w  1
#  496  1.1507604e+00 3.80e-02 4.40e+00  -5.7 2.51e-01  11.3 1.00e+00 3.05e-05h 15
#  497  1.1507639e+00 3.80e-02 4.40e+00  -5.7 9.80e+03    -  1.00e+00 3.05e-05h 16
#  498  1.1507675e+00 3.80e-02 4.40e+00  -5.7 9.80e+03    -  1.00e+00 3.05e-05h 16
#  499  1.1507710e+00 3.80e-02 4.40e+00  -5.7 9.80e+03    -  1.00e+00 3.05e-05h 16
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  500  1.1507746e+00 3.80e-02 4.40e+00  -5.7 9.80e+03    -  1.00e+00 3.05e-05h 16
#  501  1.1507783e+00 3.80e-02 4.40e+00  -5.7 9.79e+03    -  1.00e+00 3.05e-05h 16
#  502  1.1507819e+00 3.80e-02 4.40e+00  -5.7 9.79e+03    -  1.00e+00 3.05e-05h 16
#  503  1.1507856e+00 3.80e-02 4.40e+00  -5.7 9.79e+03    -  1.00e+00 3.05e-05h 16
#  504  1.1507893e+00 3.80e-02 4.40e+00  -5.7 9.79e+03    -  1.00e+00 3.05e-05h 16
#  505  1.1507930e+00 3.80e-02 4.40e+00  -5.7 9.79e+03    -  1.00e+00 3.05e-05h 16
#  506  1.4539565e+01 8.79e+01 4.24e+04  -5.7 9.79e+03    -  1.00e+00 1.00e+00w  1
#  507  1.4537902e+01 1.68e+01 6.11e+11  -5.7 5.97e-01  10.9 1.00e+00 1.00e+00w  1
#  508  1.4536208e+01 4.50e+00 1.73e+11  -5.7 3.18e-01  11.3 1.00e+00 1.00e+00w  1
#  509  1.1507967e+00 3.80e-02 4.40e+00  -5.7 2.19e-01  11.7 1.00e+00 3.05e-05h 15
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  510  1.1508005e+00 3.80e-02 4.40e+00  -5.7 9.79e+03    -  1.00e+00 3.05e-05h 16
#  511  1.1508043e+00 3.80e-02 4.40e+00  -5.7 9.78e+03    -  1.00e+00 3.05e-05h 16
#  512  1.1508081e+00 3.80e-02 4.40e+00  -5.7 9.78e+03    -  1.00e+00 3.05e-05h 16
#  513  1.1508119e+00 3.80e-02 4.40e+00  -5.7 9.78e+03    -  1.00e+00 3.05e-05h 16
#  514  1.1508158e+00 3.80e-02 4.40e+00  -5.7 9.78e+03    -  1.00e+00 3.05e-05h 16
#  515  1.1508197e+00 3.79e-02 4.40e+00  -5.7 9.78e+03    -  1.00e+00 3.05e-05h 16
#  516  1.1508236e+00 3.79e-02 4.40e+00  -5.7 9.78e+03    -  1.00e+00 3.05e-05h 16
#  517  1.1508275e+00 3.79e-02 4.40e+00  -5.7 9.77e+03    -  1.00e+00 3.05e-05h 16
#  518  1.1508315e+00 3.79e-02 4.40e+00  -5.7 9.77e+03    -  1.00e+00 3.05e-05h 16
#  519  1.4522679e+01 8.75e+01 4.23e+04  -5.7 9.77e+03    -  1.00e+00 1.00e+00w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# ...
#  772  1.1580867e+00 1.61e-02 4.17e+00  -5.7 4.35e+02    -  1.00e+00 4.88e-04h 12
#  773  1.1580996e+00 1.61e-02 4.17e+00  -5.7 4.34e+02    -  1.00e+00 4.88e-04h 12
#  774  1.1581126e+00 1.60e-02 4.17e+00  -5.7 4.34e+02    -  1.00e+00 4.88e-04h 12
#  775  1.1581255e+00 1.60e-02 4.17e+00  -5.7 4.33e+02    -  1.00e+00 4.88e-04h 12
#  776  1.1581385e+00 1.60e-02 4.16e+00  -5.7 4.32e+02    -  1.00e+00 4.88e-04h 12
#  777  1.1581514e+00 1.60e-02 4.16e+00  -5.7 4.32e+02    -  1.00e+00 4.88e-04h 12
#  778  1.2104592e+00 5.58e+00 3.20e+03  -5.7 4.31e+02    -  1.00e+00 1.00e+00w  1
#  779  1.2088547e+00 6.25e-03 5.90e+02  -5.7 1.79e+00   1.8 1.00e+00 1.00e+00w  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  780  1.2109720e+00 4.45e-03 2.61e+02  -5.7 4.81e-01   1.4 1.00e+00 1.00e+00w  1
#  781  1.1581643e+00 1.60e-02 4.16e+00  -5.7 3.12e-01   0.9 1.00e+00 4.88e-04h 11
#  782  1.1581772e+00 1.60e-02 4.16e+00  -5.7 4.30e+02    -  1.00e+00 4.88e-04h 12
#  783  1.1581901e+00 1.60e-02 4.16e+00  -5.7 4.30e+02    -  1.00e+00 4.88e-04h 12
#  784  1.1582030e+00 1.60e-02 4.15e+00  -5.7 4.29e+02    -  1.00e+00 4.88e-04h 12
#  785  1.1582159e+00 1.60e-02 4.15e+00  -5.7 4.28e+02    -  1.00e+00 4.88e-04h 12
#  786  1.1582288e+00 1.60e-02 4.15e+00  -5.7 4.28e+02    -  1.00e+00 4.88e-04h 12
#  787  1.1582417e+00 1.60e-02 4.15e+00  -5.7 4.27e+02    -  1.00e+00 4.88e-04h 12
#  788  1.1582546e+00 1.60e-02 4.15e+00  -5.7 4.26e+02    -  1.00e+00 4.88e-04h 12
#  789  1.1582675e+00 1.60e-02 4.14e+00  -5.7 4.26e+02    -  1.00e+00 4.88e-04h 12
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  790  1.1582803e+00 1.59e-02 4.14e+00  -5.7 4.25e+02    -  1.00e+00 4.88e-04h 12
#  791  1.2100769e+00 5.57e+00 3.15e+03  -5.7 4.24e+02    -  1.00e+00 1.00e+00w  1
#  792  1.2098960e+00 5.32e-03 2.17e+01  -5.7 2.02e+00   0.4 1.00e+00 1.00e+00w  1
#  793  1.2101724e+00 9.44e-05 3.02e+00  -5.7 1.61e-01  -0.1 1.00e+00 1.00e+00w  1
#  794  1.2100264e+00 2.53e-05 1.31e+00  -5.7 1.05e-01  -0.6 1.00e+00 1.00e+00h  1
#  795  1.2100064e+00 5.69e-05 1.50e+00  -5.7 3.46e-01  -1.0 1.00e+00 5.00e-01h  2
#  796  1.2100029e+00 5.75e-05 1.46e+00  -5.7 1.10e+00  -1.5 1.00e+00 3.12e-02h  6
#  797  1.2100007e+00 5.81e-05 1.45e+00  -5.7 3.01e+00  -2.0 1.00e+00 7.81e-03h  8
#  798  1.2099985e+00 5.94e-05 1.45e+00  -5.7 7.07e+00  -2.5 1.00e+00 3.91e-03h  9
#  799  1.2098361e+00 2.38e-02 1.29e+02  -5.7 1.29e+01  -2.9 1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  800  1.2080473e+00 4.03e-02 1.44e+01  -5.7 4.45e+00  -3.4 1.00e+00 1.00e+00H  1
#  801  1.2049543e+00 4.21e-02 3.17e+01  -5.7 1.09e+01  -3.9 1.00e+00 1.00e+00h  1
#  802  1.2050430e+00 5.20e-03 7.89e+00  -5.7 4.17e+00  -3.5 1.00e+00 1.00e+00h  1
#  803  1.2051020e+00 5.14e-03 7.74e+00  -5.7 1.87e+01  -3.9 1.00e+00 1.56e-02h  7
#  804  1.2067485e+00 9.35e-04 3.97e+00  -5.7 4.66e+00  -3.5 1.00e+00 1.00e+00H  1
#  805  1.2069706e+00 9.26e-04 4.13e+00  -5.7 2.06e+01  -4.0 1.00e+00 3.12e-02h  6
#  806  1.2072546e+00 8.54e-04 3.95e+00  -5.7 4.73e+00  -3.6 1.00e+00 1.25e-01h  4
#  807  1.2043065e+00 2.68e-01 1.29e+02  -5.7 2.48e+01  -4.0 1.00e+00 1.00e+00H  1
#  808  1.2041334e+00 5.62e-03 3.26e+00  -5.7 2.39e+00  -3.6 1.00e+00 1.00e+00h  1
#  809  1.2044071e+00 5.65e-03 2.75e+00  -5.7 8.42e+00  -4.1 1.00e+00 1.25e-01h  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  810  1.1988702e+00 9.67e-01 5.92e+01  -5.7 3.95e+01  -4.6 1.00e+00 1.00e+00H  1
#  811  1.1992977e+00 1.58e-02 4.89e+01  -5.7 3.37e+00  -3.2 1.00e+00 1.00e+00h  1
#  812  1.2005457e+00 1.42e-02 4.30e+01  -5.7 1.12e+01  -3.7 1.00e+00 1.25e-01h  4
#  813  1.2013017e+00 1.36e-02 4.16e+01  -5.7 2.42e+01  -4.2 1.00e+00 3.12e-02h  6
#  814  1.2027732e+00 1.42e-02 3.64e+01  -5.7 1.17e+01  -3.8 1.00e+00 1.25e-01h  4
#  815  1.2035828e+00 1.52e-02 3.52e+01  -5.7 2.51e+01  -4.2 1.00e+00 3.12e-02h  6
#  816  1.2039926e+00 1.52e-02 3.41e+01  -5.7 1.21e+01  -3.8 1.00e+00 3.12e-02h  6
#  817  1.2040960e+00 1.52e-02 3.39e+01  -5.7 2.70e+01  -4.3 1.00e+00 3.91e-03h  9
#  818  1.2041239e+00 1.52e-02 3.39e+01  -5.7 1.29e+01  -3.9 1.00e+00 1.95e-03h 10
#  819  1.2041306e+00 1.52e-02 3.39e+01  -5.7 3.07e+01  -4.4 1.00e+00 2.44e-04h 13
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  820  1.2041325e+00 1.52e-02 3.39e+01  -5.7 1.40e+01  -3.9 1.00e+00 1.22e-04h 14
#  821  1.2059200e+00 1.85e-02 3.05e+01  -5.7 3.69e+01  -4.4 1.00e+00 6.25e-02h  5
#  822  1.2240263e+00 5.77e-01 3.04e+01  -5.7 1.43e+01  -4.0 1.00e+00 1.00e+00w  1
#  823  1.2399796e+00 1.52e-01 1.88e+02  -5.7 1.67e+01  -4.5 1.00e+00 1.00e+00w  1
#  824  1.2209884e+00 1.40e-01 2.60e+10  -5.7 1.87e+01  -4.9 1.00e+00 1.00e+00w  1
# WARNING: Problem in step computation; switching to emergency mode.
#  825  1.2069324e+00 1.96e-02 2.85e+01  -5.7 1.87e+01  20.0 1.00e+00 6.25e-02h  5
#  826  1.2199584e+00 3.65e-03 5.67e+01  -5.7 1.43e+01  -4.0 1.00e+00 1.00e+00H  1
#  827  1.2198508e+00 2.83e-03 3.46e+00  -5.7 8.60e+00  -4.5 1.00e+00 1.00e+00H  1
#  828  1.2183277e+00 6.56e-04 2.91e-01  -5.7 5.23e+00  -5.0 1.00e+00 1.00e+00h  1
#  829  1.2134983e+00 8.47e-03 2.21e+00  -5.7 1.58e+01  -5.4 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  830  1.2055909e+00 3.24e-03 1.65e+00  -5.7 3.64e+01  -5.9 1.00e+00 1.00e+00H  1
#  831  1.2036741e+00 1.80e-03 2.96e-02  -5.7 1.18e+01  -5.5 1.00e+00 1.00e+00h  1
#  832  1.2000419e+00 1.21e-02 1.71e-02  -5.7 2.69e+01  -6.0 1.00e+00 1.00e+00h  1
#  833  1.1954909e+00 8.49e-02 1.67e-01  -5.7 4.32e+01  -6.4 1.00e+00 1.00e+00h  1
#  834  1.1956186e+00 7.14e-02 1.32e+09  -5.7 3.83e+02    -  1.00e+00 1.25e-01h  4
#  835  1.1947837e+00 2.61e-01 2.75e+26  -5.7 1.34e+02  -6.9 1.00e+00 1.00e+00h  1
# WARNING: Problem in step computation; switching to emergency mode.
#  836r 1.1947837e+00 2.61e-01 9.99e+02  -0.6 0.00e+00  18.9 0.00e+00 0.00e+00R  1
#  837r 1.1947909e+00 6.75e-02 9.74e+02  -0.6 3.72e+02    -  2.53e-02 9.90e-04f  1
#  838  1.1878065e+00 3.58e+00 5.15e+00  -5.7 3.21e+02    -  1.00e+00 1.00e+00h  1
# WARNING: Problem in step computation; switching to emergency mode.
#  839r 1.1878065e+00 3.58e+00 9.99e+02   0.6 0.00e+00    -  0.00e+00 0.00e+00R  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  840r 1.1882685e+00 9.16e-01 9.83e+02   0.6 3.58e+03    -  1.32e-01 9.91e-04f  1
#  841  1.1778291e+00 3.31e+00 1.76e+00  -5.7 2.29e+02    -  1.00e+00 1.00e+00h  1
#  842  1.1792397e+00 1.31e+00 3.98e+05  -5.7 4.18e+02    -  1.00e+00 5.00e-01h  2
#  843r 1.1792397e+00 1.31e+00 9.99e+02   0.1 0.00e+00  20.0 0.00e+00 4.77e-07R 22
#  844r 1.1794200e+00 3.23e-01 9.72e+02   0.1 1.86e+03    -  2.85e-02 1.06e-03f  1
#  845  1.1689332e+00 2.98e+00 9.51e-01  -5.7 6.11e+02    -  1.00e+00 1.00e+00H  1
#  846  1.1765919e+00 2.97e+00 4.92e+07  -5.7 7.84e+03    -  1.00e+00 6.25e-02h  5
#  847  1.1765919e+00 2.97e+00 1.40e+13  -5.7 4.43e-07  19.5 1.00e+00 1.00e+00h  1
#  848  1.1765919e+00 2.97e+00 2.79e+13  -5.7 2.65e-06  19.0 1.00e+00 1.00e+00h  1
#  849  1.1765919e+00 2.94e+00 4.17e+13  -5.7 1.19e-05  18.5 1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  850  1.1765919e+00 2.85e+00 5.50e+13  -5.7 4.71e-05  18.1 1.00e+00 1.00e+00h  1
#  851  1.1765919e+00 2.49e+00 6.64e+13  -5.7 1.70e-04  17.6 1.00e+00 1.00e+00h  1
#  852  1.1765919e+00 1.42e+00 7.16e+13  -5.7 5.51e-04  17.1 1.00e+00 1.00e+00h  1
#  853  1.1765919e+00 1.35e+00 4.32e+13  -5.7 1.39e-03  16.6 1.00e+00 1.00e+00H  1
#  854  1.1765919e+00 1.39e+00 1.79e+13  -5.7 1.38e-03  16.2 1.00e+00 1.00e+00H  1
#  855  1.1765919e+00 1.46e+00 1.06e+13  -5.7 2.77e-03  15.7 1.00e+00 1.00e+00H  1
#  856  1.1765920e+00 9.59e-01 6.75e+12  -5.7 5.42e-03  15.2 1.00e+00 1.00e+00H  1
#  857  1.1765921e+00 1.31e+00 3.37e+12  -5.7 1.04e-02  14.7 1.00e+00 1.00e+00H  1
#  858  1.1765927e+00 1.13e+00 1.25e+12  -5.7 1.20e-02  14.3 1.00e+00 1.00e+00H  1
#  859  1.1765963e+00 6.89e-01 2.90e+11  -5.7 1.03e-02  13.8 1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  860  1.1766110e+00 6.37e-01 2.09e+11  -5.7 1.37e-02  13.3 1.00e+00 1.00e+00H  1
#  861  1.1766739e+00 4.60e-01 8.87e+10  -5.7 2.36e-02  12.8 1.00e+00 1.00e+00H  1
#  862  1.1769748e+00 3.25e-01 3.59e+10  -5.7 2.77e-02  12.3 1.00e+00 1.00e+00H  1
#  863  1.1780309e+00 3.71e-01 1.38e+10  -5.7 2.78e-02  11.9 1.00e+00 1.00e+00H  1
#  864  1.1813383e+00 3.44e-01 9.32e+09  -5.7 4.72e-02  11.4 1.00e+00 1.00e+00H  1
#  865  1.1825750e+00 3.68e-01 7.08e+09  -5.7 1.09e-02  11.8 1.00e+00 1.00e+00h  1
#  866  1.1853196e+00 3.65e-01 2.89e+18  -5.7 2.77e+03  11.3 1.00e+00 7.81e-03h  8
# WARNING: Problem in step computation; switching to emergency mode.
#  867r 1.1853196e+00 3.65e-01 9.99e+02  -0.4 0.00e+00  19.2 0.00e+00 0.00e+00R  1
#  868r 1.1848117e+00 8.60e-02 9.96e+02  -0.4 4.22e+03    -  2.59e-02 1.06e-03f  1
#  869  1.1856184e+00 8.72e-02 1.17e+02  -5.7 1.53e+04    -  1.00e+00 1.95e-03h 10
# WARNING: Problem in step computation; switching to emergency mode.
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  870r 1.1856184e+00 8.72e-02 9.99e+02  -1.1 0.00e+00    -  0.00e+00 0.00e+00R  1
#  871r 1.1873414e+00 3.32e-02 9.77e+02  -1.1 4.98e+03    -  9.13e-02 9.91e-04f  1
#  872  1.1881283e+00 3.36e-02 4.59e+06  -5.7 1.46e+04    -  1.00e+00 1.95e-03h 10
# WARNING: Problem in step computation; switching to emergency mode.
#  873r 1.1881283e+00 3.36e-02 9.99e+02  -1.5 0.00e+00    -  0.00e+00 0.00e+00R  1
#  874r 1.1911050e+00 4.14e-02 9.85e+02  -1.5 5.65e+03    -  4.63e-02 9.90e-04f  1
#  875r 1.1904827e+00 1.08e-01 9.37e+02  -1.5 8.52e+02    -  8.53e-02 3.17e-02f  1
#  876r 1.1863990e+00 1.46e-01 8.98e+02  -1.5 1.54e+02    -  3.83e-02 5.22e-02f  1
#  877r 1.1849234e+00 1.58e-01 7.97e+02  -1.5 1.06e+02    -  1.10e-01 6.54e-02f  1
#  878r 1.1831259e+00 1.64e-01 5.64e+02  -1.5 5.20e+01    -  3.35e-01 1.76e-01f  1
#  879r 1.1815904e+00 9.36e-02 2.82e+02  -1.5 2.57e+01    -  1.00e+00 5.07e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  880r 1.1812763e+00 6.58e-04 1.14e-01  -1.5 1.44e+01    -  1.00e+00 1.00e+00f  1
#  881  1.1581711e+00 3.67e+00 3.09e+00  -5.7 4.87e+02    -  1.00e+00 1.00e+00h  1
#  882  1.1581711e+00 3.67e+00 1.10e+13  -5.7 1.96e-07  19.8 1.00e+00 1.00e+00h  1
#  883  1.1581711e+00 3.67e+00 2.20e+13  -5.7 1.17e-06  19.3 1.00e+00 1.00e+00h  1
#  884  1.1581711e+00 3.67e+00 3.29e+13  -5.7 5.26e-06  18.8 1.00e+00 1.00e+00h  1
#  885  1.1581711e+00 3.66e+00 4.31e+13  -5.7 2.07e-05  18.3 1.00e+00 1.00e+00h  1
#  886  1.1581711e+00 3.61e+00 5.13e+13  -5.7 7.39e-05  17.8 1.00e+00 1.00e+00h  1
#  887  1.1581711e+00 3.47e+00 5.31e+13  -5.7 2.29e-04  17.4 1.00e+00 1.00e+00h  1
#  888  1.1581711e+00 3.13e+00 3.30e+13  -5.7 5.25e-04  16.9 1.00e+00 1.00e+00H  1
#  889  1.1581711e+00 2.61e+00 3.37e+13  -5.7 1.21e-03  16.4 1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  890  1.1581711e+00 1.59e+00 3.44e+13  -5.7 4.02e-03  15.9 1.00e+00 1.00e+00h  1
#  891  1.1581711e+00 1.98e+00 2.52e+13  -5.7 1.07e-02  15.5 1.00e+00 1.00e+00H  1
#  892  1.1581712e+00 1.94e+00 5.99e+12  -5.7 1.63e-02  15.0 1.00e+00 1.00e+00H  1
#  893  1.1581713e+00 1.76e+00 2.81e+12  -5.7 1.13e-02  14.5 1.00e+00 1.00e+00H  1
#  894  1.1581711e+00 1.55e+00 1.45e+12  -5.7 2.09e-02  14.0 1.00e+00 1.00e+00H  1
#  895  1.1581756e+00 9.05e-01 7.10e+11  -5.7 2.30e-02  13.5 1.00e+00 1.00e+00H  1
#  896  1.1582089e+00 8.97e-01 2.16e+11  -5.7 3.78e-02  13.1 1.00e+00 1.00e+00H  1
#  897  1.1583435e+00 5.99e-01 8.49e+10  -5.7 3.92e-02  12.6 1.00e+00 1.00e+00H  1
#  898  1.1587454e+00 6.41e-01 3.95e+10  -5.7 3.56e-02  12.1 1.00e+00 1.00e+00H  1
#  899  1.1597428e+00 4.63e-01 2.10e+10  -5.7 5.81e-02  11.6 1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  900  1.1605255e+00 7.56e+00 2.29e+11  -5.7 2.51e-01  11.2 1.00e+00 1.00e+00H  1
#  901  1.1649949e+00 3.30e+00 1.48e+11  -5.7 2.69e-01  10.7 1.00e+00 1.00e+00h  1
#  902  1.1676664e+00 7.46e-01 8.87e+09  -5.7 6.62e-02  11.1 1.00e+00 1.00e+00h  1
#  903  1.1787894e+00 3.65e-01 5.00e+09  -5.7 8.21e-02  10.6 1.00e+00 1.00e+00h  1
#  904  1.1790749e+00 3.62e-01 4.97e+09  -5.7 1.56e+00  10.2 1.00e+00 7.81e-03h  8
#  905  1.1809467e+00 3.17e-01 4.66e+09  -5.7 6.48e-02  10.6 1.00e+00 1.25e-01h  4
#  906  1.1811298e+00 3.07e-01 4.61e+09  -5.7 3.14e-02  11.0 1.00e+00 3.12e-02h  6
#  907  1.1811439e+00 3.07e-01 1.27e+16  -5.7 4.67e+04  10.5 1.00e+00 1.22e-04h 14
# WARNING: Problem in step computation; switching to emergency mode.
#  908r 1.1811439e+00 3.07e-01 9.99e+02  -0.5 0.00e+00  19.9 0.00e+00 0.00e+00R  1
#  909r 1.1678121e+00 3.00e-01 9.82e+02  -0.5 7.95e+02    -  2.25e-01 9.90e-04f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  910r 1.1703636e+00 3.48e-01 9.08e+02  -0.5 7.95e+01    -  9.85e-02 1.94e-01f  1
#  911r 1.1649259e+00 2.47e-01 2.20e+02  -0.5 1.39e+01    -  1.00e+00 2.86e-01f  1
#  912  1.1474843e+00 5.33e+00 1.46e+00  -5.7 5.62e+02    -  1.00e+00 1.00e+00h  1
#  913  1.1523356e+00 2.81e-01 3.64e+01  -5.7 1.00e+01  -4.0 1.00e+00 1.00e+00h  1
#  914  1.1656261e+00 3.44e-02 1.95e+01  -5.7 1.73e+01  -4.5 1.00e+00 1.00e+00H  1
#  915  1.1686234e+00 5.52e-03 4.82e+00  -5.7 3.17e+00  -4.1 1.00e+00 1.00e+00h  1
#  916  1.1677345e+00 2.23e-02 1.58e+00  -5.7 4.31e+00  -4.5 1.00e+00 1.00e+00H  1
#  917  1.1668901e+00 6.13e-04 3.62e-01  -5.7 9.10e-01  -5.0 1.00e+00 1.00e+00h  1
#  918  1.1610350e+00 4.38e-01 1.25e-01  -5.7 7.13e+02    -  1.00e+00 2.50e-01h  3
#  919  1.1591712e+00 4.40e-01 8.79e-02  -5.7 5.82e+02    -  1.00e+00 1.25e-01h  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  920  1.1514873e+00 1.67e+00 3.08e-01  -5.7 5.16e+02    -  1.00e+00 1.00e+00H  1
#  921  1.1519562e+00 1.46e+00 2.71e-01  -5.7 1.17e+02    -  1.00e+00 1.25e-01h  4
#  922  1.1522910e+00 1.27e+00 2.39e-01  -5.7 1.04e+02    -  1.00e+00 1.25e-01h  4
#  923  1.1552760e+00 1.43e-01 1.48e-01  -5.7 9.48e+01    -  1.00e+00 1.00e+00h  1
#  924  1.1527932e+00 2.57e-02 1.33e-01  -5.7 5.04e+01    -  1.00e+00 1.00e+00h  1
#  925  1.1528691e+00 1.77e-03 2.79e-03  -5.7 1.13e+01    -  1.00e+00 1.00e+00h  1
#  926  1.1528582e+00 8.42e-06 3.95e-06  -5.7 3.24e-01    -  1.00e+00 1.00e+00h  1
#  927  1.1528583e+00 3.83e-10 7.84e-12  -8.6 1.10e-03    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 927
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.1528583224799054e+00    1.1528583224799054e+00
# Dual infeasibility......:   7.8440032247328872e-12    7.8440032247328872e-12
# Constraint violation....:   3.8275693725609017e-10    3.8275693725609017e-10
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   3.8275693725609017e-10    3.8275693725609017e-10
#
#
# Number of objective function evaluations             = 7464
# Number of objective gradient evaluations             = 886
# Number of equality constraint evaluations            = 7484
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 946
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 927
# Total seconds in IPOPT                               = 649.147
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
# callback_fun  |   3.92 s (  4.50ms)  90.41 s (103.80ms)       871
#        nlp_f  |  12.12 s (  1.62ms) 783.04ms (104.91us)      7464
#        nlp_g  | 250.81 s ( 33.51ms)  16.19 s (  2.16ms)      7484
#   nlp_grad_f  |   4.14 s (  4.67ms) 276.60ms (311.84us)       887
#   nlp_hess_l  | 230.17 s (256.89ms) 230.03 s (256.73ms)       896
#    nlp_jac_g  | 712.74 s (752.63ms) 131.68 s (139.04ms)       947
#        total  |   3.87ks (  3.87ks) 649.15 s (649.15 s)         1

# %% [markdown]
# You can finally display the result.

# %%
# %load tp3/generated/contact_ocp6
print("***** Display the resulting trajectory ...")
displayScene(robot.q0, 1)
displayTraj([x[:nq] for x in sol_xs], DT)
# Out:
# ***** Display the resulting trajectory ...
